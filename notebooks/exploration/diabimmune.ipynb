# %%
# Exploring DIABIMMUNE data
# %load_ext autoreload
# %autoreload 2

# !pip install pyreadr
# !pip install openpyxl

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
from tqdm import tqdm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Requirement already satisfied: pyreadr in /data/phil/miniconda3/envs/aPTR/lib/python3.6/site-packages (0.4.4)
# Requirement already satisfied: pandas>0.24.0 in /data/phil/miniconda3/envs/aPTR/lib/python3.6/site-packages (from pyreadr) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /data/phil/miniconda3/envs/aPTR/lib/python3.6/site-packages (from pandas>0.24.0->pyreadr) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/phil/.local/lib/python3.6/site-packages (from pandas>0.24.0->pyreadr) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /data/phil/miniconda3/envs/aPTR/lib/python3.6/site-packages (from pandas>0.24.0->pyreadr) (1.17.0)
# Requirement already satisfied: six>=1.5 in /home/phil/.local/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>0.24.0->pyreadr) (1.16.0)
# Requirement already satisfied: openpyxl in /data/phil/miniconda3/envs/aPTR/lib/python3.6/site-packages (3.1.0)
# Requirement already satisfied: et-xmlfile in /data/phil/miniconda3/envs/aPTR/lib/python3.6/site-packages (from openpyxl) (1.1.0)

# %%
# Get rdata from internet: 
# result = pyreadr.read_r('data/diabimmune.rda')

diabimmune_metadata = pd.read_table("./diabimmune.tsv")
diabimmune_metadata.head()
# Out:
#   subjectID country  sampleID  age_at_collection cohort gid_wgs gid_16s
# 0   E000823     FIN   3000150                 56    abx     NaN  G74397
# 1   E000823     FIN   3102720                259    abx     NaN  G69867
# 2   E000823     FIN   3114328                760    abx     NaN  G74423
# 3   E000823     FIN   3106240                511    abx     NaN  G74306
# 4   E000823     FIN   3000042                151    abx     NaN  G69730

# %%
diabimmune_both = diabimmune_metadata.dropna()
print(len(diabimmune_both) / len(diabimmune_metadata) * 100) # 30% of the data is available
print(len(diabimmune_both))
# Out:
# 30.128396536279485
# 1009

# %%
# How many distinct subjects?
n_subjects = len(diabimmune_both['subjectID'].unique())
print(n_subjects)
print(len(diabimmune_both) / n_subjects) # 4 samples per subject, on average
# Out:
# 257
# 3.9260700389105057

# %%
# At this point, I have downloaded all of the 16S reads. They are in the dir
# ~/DATA/diabimmune/reads

# I will now move these files to ~/DATA/diabimmune/16s_shared/reads

! mkdir -p ~/DATA/diabimmune/16s_shared/reads

for i in range(len(diabimmune_both)):
    ! mv ~/DATA/diabimmune/reads/{diabimmune_both.iloc[i]['gid_16s']}* ~/DATA/diabimmune/16s_shared/reads/
# Out:
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G74454*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G69809*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G68498*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G36025*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G36451*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G35881*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G35867*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G69741*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G68204*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G68224*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G75872*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G75855*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G73882*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G75694*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G75788*
# zsh:1: no matches found: /home/phil/DATA/diabimmune/reads/G66253*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     156             else:
# --> 157                 child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     158             flush = sys.stdout.flush
#
# ~/.local/lib/python3.6/site-packages/pexpect/pty_spawn.py in __init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204         else:
# --> 205             self._spawn(command, args, preexec_fn, dimensions)
#     206         self.use_poll = use_poll
#
# ~/.local/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawn(self, command, args, preexec_fn, dimensions)
#     303         self.ptyproc = self._spawnpty(self.args, env=self.env,
# --> 304                                      cwd=self.cwd, **kwargs)
#     305
#
# ~/.local/lib/python3.6/site-packages/pexpect/pty_spawn.py in _spawnpty(self, args, **kwargs)
#     314         '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315         return ptyprocess.PtyProcess.spawn(args, **kwargs)
#     316
#
# ~/.local/lib/python3.6/site-packages/ptyprocess/ptyprocess.py in spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314         os.close(exec_err_pipe_write)
# --> 315         exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316         os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-59a8855e95e5> in <module>
#       7
#       8 for i in range(len(diabimmune_both)):
# ----> 9     get_ipython().system(" mv ~/DATA/diabimmune/reads/{diabimmune_both.iloc[i]['gid_16s']}* ~/DATA/diabimmune/16s_shared/reads/")
#
# ~/.local/lib/python3.6/site-packages/ipykernel/zmqshell.py in system_piped(self, cmd)
#     648                 self.user_ns['_exit_code'] = system(cmd)
#     649         else:
# --> 650             self.user_ns['_exit_code'] = system(self.var_expand(cmd, depth=1))
#     651
#     652     # Ensure new system_piped implementation is used
#
# ~/.local/lib/python3.6/site-packages/IPython/utils/_process_posix.py in system(self, cmd)
#     171             # (the character is known as ETX for 'End of Text', see
#     172             # curses.ascii.ETX).
# --> 173             child.sendline(chr(3))
#     174             # Read and print any more output the program might produce on its
#     175             # way out.
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
# We need to download the corresponding WGS reads

! mkdir -p ~/DATA/diabimmune/wgs_shared
! mkdir -p ~/DATA/diabimmune/wgs_shared/reads

for id in tqdm(diabimmune_both['gid_wgs']):
    if not os.path.exists(f"~/DATA/diabimmune/wgs_shared/reads/{id}_R1.fastq.gz"):
        ! wget https://diabimmune.broadinstitute.org/diabimmune/data/20/{id}_R1.fastq.gz
    if not os.path.exists(f"~/DATA/diabimmune/wgs_shared/reads/{id}_R2.fastq.gz"):
        ! wget https://diabimmune.broadinstitute.org/diabimmune/data/20/{id}_R2.fastq.gz
    if not os.path.exists(f"~/DATA/diabimmune/wgs_shared/reads/{id}_unpaired.fastq.gz"):
        ! wget https://diabimmune.broadinstitute.org/diabimmune/data/20/{id}_unpaired.fastq.gz
    ! mv {id}_*.fastq.gz ~/DATA/diabimmune/wgs_shared/reads/
# Out:
#   0%|          | 0/1009 [00:00<?, ?it/s]
# --2023-02-12 16:33:50--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G80124_R1.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 711032697 (678M) [application/x-gzip]
# Saving to: ‘G80124_R1.fastq.gz’
#
# G80124_R1.fastq.gz  100%[===================>] 678.09M  19.2MB/s    in 35s
#
# 2023-02-12 16:34:26 (19.2 MB/s) - ‘G80124_R1.fastq.gz’ saved [711032697/711032697]
#
# --2023-02-12 16:34:26--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G80124_R2.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689083198 (657M) [application/x-gzip]
# Saving to: ‘G80124_R2.fastq.gz’
#
# G80124_R2.fastq.gz  100%[===================>] 657.16M  19.2MB/s    in 34s
#
# 2023-02-12 16:35:01 (19.1 MB/s) - ‘G80124_R2.fastq.gz’ saved [689083198/689083198]
#
# --2023-02-12 16:35:01--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G80124_unpaired.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-12 16:35:01 ERROR 404: Not Found.
#   0%|          | 1/1009 [01:19<22:13:00, 79.35s/it]
# --2023-02-12 16:35:10--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G79049_R1.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 139590801 (133M) [application/x-gzip]
# Saving to: ‘G79049_R1.fastq.gz’
#
# G79049_R1.fastq.gz  100%[===================>] 133.12M  19.2MB/s    in 7.0s
#
# 2023-02-12 16:35:17 (19.1 MB/s) - ‘G79049_R1.fastq.gz’ saved [139590801/139590801]
#
# --2023-02-12 16:35:17--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G79049_R2.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 132976352 (127M) [application/x-gzip]
# Saving to: ‘G79049_R2.fastq.gz’
#
# G79049_R2.fastq.gz  100%[===================>] 126.82M  19.2MB/s    in 6.6s
#
# 2023-02-12 16:35:24 (19.1 MB/s) - ‘G79049_R2.fastq.gz’ saved [132976352/132976352]
#
# --2023-02-12 16:35:25--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G79049_unpaired.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-12 16:35:25 ERROR 404: Not Found.
#   0%|          | 2/1009 [01:36<12:01:32, 42.99s/it]
# --2023-02-12 16:35:27--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G78999_R1.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 585215567 (558M) [application/x-gzip]
# Saving to: ‘G78999_R1.fastq.gz’
#
# G78999_R1.fastq.gz    4%[                    ]  26.05M  18.6MB/s               ^C
# --2023-02-12 16:35:29--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G78999_R2.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 563767264 (538M) [application/x-gzip]
# Saving to: ‘G78999_R2.fastq.gz’
#
# G78999_R2.fastq.gz  100%[===================>] 537.65M  19.1MB/s    in 28s
#
# 2023-02-12 16:35:58 (19.1 MB/s) - ‘G78999_R2.fastq.gz’ saved [563767264/563767264]
#
# --2023-02-12 16:35:58--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G78999_unpaired.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-02-12 16:35:58 ERROR 404: Not Found.
#   0%|          | 3/1009 [02:12<11:00:52, 39.42s/it]
# --2023-02-12 16:36:02--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G45069_R1.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 595936467 (568M) [application/x-gzip]
# Saving to: ‘G45069_R1.fastq.gz’
#
# G45069_R1.fastq.gz   31%[=====>              ] 179.98M  18.0MB/s    eta 21s    ^C
# --2023-02-12 16:36:13--  https://diabimmune.broadinstitute.org/diabimmune/data/20/G45069_R2.fastq.gz
# Resolving diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)... 69.173.93.60
# Connecting to diabimmune.broadinstitute.org (diabimmune.broadinstitute.org)|69.173.93.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 584477159 (557M) [application/x-gzip]
# Saving to: ‘G45069_R2.fastq.gz’
#
# G45069_R2.fastq.gz   49%[========>           ] 275.51M  19.2MB/s    eta 15s

# %%
# Which samples did aPTR return a result for?

aptr_out = pd.read_table(
    "/home/phil/aptr/experiments/diabimmune/16s_shared/aptr_8223c61e-4f69-4350-afb5-3b096f484af1/inferred_ptrs.tsv",
    dtype={0: str},
)
aptr_out = aptr_out.set_index(aptr_out.columns[0])
aptr_estimates = aptr_out.loc[:,aptr_out.sum(axis=0) > 0].columns 
print(len(aptr_estimates))
# Out:
# 78

# %%
# Move corresponding WGS reads to a special directory - 78 samples

# First, make a dictionary to convert sample IDs
wgs_to_rna = dict(zip(diabimmune_both['gid_wgs'], diabimmune_both['gid_16s']))
rna_to_wgs = dict(zip(diabimmune_both['gid_16s'], diabimmune_both['gid_wgs']))

! mkdir -p ~/DATA/diabimmune/wgs_aptr/reads

for rna_id in aptr_estimates:
    rna_id = rna_id.split("_")[0]
    wgs_id = rna_to_wgs[rna_id]
    ! cp ~/DATA/diabimmune/wgs_shared/reads/{wgs_id}_R1.fastq.gz ~/DATA/diabimmune/wgs_aptr/reads
    ! cp ~/DATA/diabimmune/wgs_shared/reads/{wgs_id}_R2.fastq.gz ~/DATA/diabimmune/wgs_aptr/reads

# %% [markdown]
# # Run coPTR on matched WGS reads
# This must be run using the `coPTR` conda environment

# %%
# First, make an index for the relevant genomes
import pandas as pd

aptr_out = pd.read_table(
    "/home/phil/aptr/experiments/diabimmune/16s_shared/aptr_8223c61e-4f69-4350-afb5-3b096f484af1/inferred_ptrs.tsv",
    dtype={0: str},
)
aptr_genomes = aptr_out.iloc[:,0]

! mkdir -p ~/DATA/diabimmune/wgs_aptr/coptr_out/seqs
! mkdir -p ~/DATA/diabimmune/wgs_aptr/coptr_out/index

for genome_id in aptr_genomes:
    ! cp ~/aptr/data/seqs/{genome_id}.fna ~/DATA/diabimmune/wgs_aptr/coptr_out/seqs

# Create coPTR index
! coptr index ~/DATA/diabimmune/wgs_aptr/coptr_out/seqs ~/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs
# Out:
# [INFO] [Feb 12, 2023 17:07:11] [coptr.read_mapper] Found 16 files totaling 0.0543 GB.
# [INFO] [Feb 12, 2023 17:07:11] [coptr.read_mapper] Copying FASTA files to coptr-fna-2023-02-12T22:07:11+00:00.fna with prepended genome ids (filenames).
# [INFO] [Feb 12, 2023 17:07:12] [coptr.read_mapper] Writing 16 reference genome ids to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs.genomes.
# [INFO] [Feb 12, 2023 17:07:12] [coptr.read_mapper] bowtie2-build coptr-fna-2023-02-12T22:07:11+00:00.fna /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs --threads 1
# Settings:
#   Output files: "/home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   coptr-fna-2023-02-12T22:07:11+00:00.fna
# Building a SMALL index
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
# bmax according to bmaxDivN setting: 14332445
# Using parameters --bmax 10749334 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 10749334 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:01
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 5.73298e+07 (target: 10749333)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 1
#   No samples; assembling all-inclusive block
#   Sorting block of length 57329783 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:00:11
# Returning block of 57329784 for bucket 1
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 15926696
# fchr[G]: 28664326
# fchr[T]: 41347056
# fchr[$]: 57329783
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 23312845 bytes to primary EBWT file: /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs.1.bt2
# Wrote 14332452 bytes to secondary EBWT file: /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 57329783
#     bwtLen: 57329784
#     sz: 14332446
#     bwtSz: 14332446
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 3583112
#     offsSz: 14332448
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 298593
#     numLines: 298593
#     ebwtTotLen: 19109952
#     ebwtTotSz: 19109952
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 00:00:17
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
#   Time to reverse reference sequence: 00:00:00
# bmax according to bmaxDivN setting: 14332445
# Using parameters --bmax 10749334 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 10749334 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:01
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 5.73298e+07 (target: 10749333)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 1
#   No samples; assembling all-inclusive block
#   Sorting block of length 57329783 for bucket 1
#   (Using difference cover)
#   Sorting block time: 00:00:11
# Returning block of 57329784 for bucket 1
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 15926696
# fchr[G]: 28664326
# fchr[T]: 41347056
# fchr[$]: 57329783
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 23312845 bytes to primary EBWT file: /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs.rev.1.bt2
# Wrote 14332452 bytes to secondary EBWT file: /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs.rev.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 57329783
#     bwtLen: 57329784
#     sz: 14332446
#     bwtSz: 14332446
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 3583112
#     offsSz: 14332448
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 298593
#     numLines: 298593
#     ebwtTotLen: 19109952
#     ebwtTotSz: 19109952
#     color: 0
#     reverse: 1
# Total time for backward call to driver() for mirror index: 00:00:17
# [INFO] [Feb 12, 2023 17:07:46] [coptr.read_mapper] Indexed 16 FASTA files for the reference database.
# [INFO] [Feb 12, 2023 17:07:46] [coptr.read_mapper] Cleaning up coptr-fna-2023-02-12T22:07:11+00:00.fna.

# %%
# Run coPTR
import os

outdir = "/home/phil/DATA/diabimmune/wgs_aptr/coptr_out"
readdir = "/home/phil/DATA/diabimmune/wgs_aptr/reads"

# Make dirs
! mkdir -p {outdir}/bam
! mkdir -p {outdir}/coverage_maps

# coPTR assumes reads end in _1 and _2, not _R1 and _R2 (idempotent batch rename):
for file in os.listdir(readdir):
    if file.endswith("_R1.fastq.gz"):
        ! mv {readdir}/{file} {readdir}/{file.replace("_R1", "_1")}
    if file.endswith("_R2.fastq.gz"):
        ! mv {readdir}/{file} {readdir}/{file.replace("_R2", "_2")}

# coPTR commands
! coptr map {outdir}/index/seqs {readdir} {outdir}/bam --threads 12 --paired
! coptr extract {outdir}/bam {outdir}/coverage_maps
! coptr estimate {outdir}/coverage_maps {outdir}/coptr_log2_ptrs.tsv
! coptr count {outdir}/coverage_maps {outdir}/coptr_counts.tsv
# Out:
# [INFO] [Feb 12, 2023 17:19:46] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45050.sam
# [INFO] [Feb 12, 2023 17:19:46] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45050_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45050_2.fastq.gz --no-unal -p 12 -k 10
# 7822277 reads; of these:
#   7822277 (100.00%) were paired; of these:
#     7460354 (95.37%) aligned concordantly 0 times
#     336174 (4.30%) aligned concordantly exactly 1 time
#     25749 (0.33%) aligned concordantly >1 times
#     ----
#     7460354 pairs aligned concordantly 0 times; of these:
#       171313 (2.30%) aligned discordantly 1 time
#     ----
#     7289041 pairs aligned 0 times concordantly or discordantly; of these:
#       14578082 mates make up the pairs; of these:
#         14479497 (99.32%) aligned 0 times
#         60852 (0.42%) aligned exactly 1 time
#         37733 (0.26%) aligned >1 times
# 7.45% overall alignment rate
# [INFO] [Feb 12, 2023 17:20:57] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45050.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45050.bam.
# [INFO] [Feb 12, 2023 17:21:05] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45050.sam.
# [INFO] [Feb 12, 2023 17:21:05] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45054.sam
# [INFO] [Feb 12, 2023 17:21:05] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45054_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45054_2.fastq.gz --no-unal -p 12 -k 10
# 7945407 reads; of these:
#   7945407 (100.00%) were paired; of these:
#     7381168 (92.90%) aligned concordantly 0 times
#     542229 (6.82%) aligned concordantly exactly 1 time
#     22010 (0.28%) aligned concordantly >1 times
#     ----
#     7381168 pairs aligned concordantly 0 times; of these:
#       284823 (3.86%) aligned discordantly 1 time
#     ----
#     7096345 pairs aligned 0 times concordantly or discordantly; of these:
#       14192690 mates make up the pairs; of these:
#         14131364 (99.57%) aligned 0 times
#         29581 (0.21%) aligned exactly 1 time
#         31745 (0.22%) aligned >1 times
# 11.07% overall alignment rate
# [INFO] [Feb 12, 2023 17:22:24] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45054.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45054.bam.
# [INFO] [Feb 12, 2023 17:22:34] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45054.sam.
# [INFO] [Feb 12, 2023 17:22:34] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45056.sam
# [INFO] [Feb 12, 2023 17:22:34] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45056_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45056_2.fastq.gz --no-unal -p 12 -k 10
# 8166853 reads; of these:
#   8166853 (100.00%) were paired; of these:
#     6851464 (83.89%) aligned concordantly 0 times
#     1272982 (15.59%) aligned concordantly exactly 1 time
#     42407 (0.52%) aligned concordantly >1 times
#     ----
#     6851464 pairs aligned concordantly 0 times; of these:
#       572627 (8.36%) aligned discordantly 1 time
#     ----
#     6278837 pairs aligned 0 times concordantly or discordantly; of these:
#       12557674 mates make up the pairs; of these:
#         12449175 (99.14%) aligned 0 times
#         59316 (0.47%) aligned exactly 1 time
#         49183 (0.39%) aligned >1 times
# 23.78% overall alignment rate
# [INFO] [Feb 12, 2023 17:24:20] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45056.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45056.bam.
# [INFO] [Feb 12, 2023 17:24:42] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45056.sam.
# [INFO] [Feb 12, 2023 17:24:42] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45067.sam
# [INFO] [Feb 12, 2023 17:24:42] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45067_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45067_2.fastq.gz --no-unal -p 12 -k 10
# 8627898 reads; of these:
#   8627898 (100.00%) were paired; of these:
#     8292504 (96.11%) aligned concordantly 0 times
#     319339 (3.70%) aligned concordantly exactly 1 time
#     16055 (0.19%) aligned concordantly >1 times
#     ----
#     8292504 pairs aligned concordantly 0 times; of these:
#       141732 (1.71%) aligned discordantly 1 time
#     ----
#     8150772 pairs aligned 0 times concordantly or discordantly; of these:
#       16301544 mates make up the pairs; of these:
#         16250599 (99.69%) aligned 0 times
#         26214 (0.16%) aligned exactly 1 time
#         24731 (0.15%) aligned >1 times
# 5.83% overall alignment rate
# [INFO] [Feb 12, 2023 17:25:58] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45067.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45067.bam.
# [INFO] [Feb 12, 2023 17:26:04] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45067.sam.
# [INFO] [Feb 12, 2023 17:26:04] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45072.sam
# [INFO] [Feb 12, 2023 17:26:04] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45072_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45072_2.fastq.gz --no-unal -p 12 -k 10
# 9256966 reads; of these:
#   9256966 (100.00%) were paired; of these:
#     7778860 (84.03%) aligned concordantly 0 times
#     1432388 (15.47%) aligned concordantly exactly 1 time
#     45718 (0.49%) aligned concordantly >1 times
#     ----
#     7778860 pairs aligned concordantly 0 times; of these:
#       573937 (7.38%) aligned discordantly 1 time
#     ----
#     7204923 pairs aligned 0 times concordantly or discordantly; of these:
#       14409846 mates make up the pairs; of these:
#         14280260 (99.10%) aligned 0 times
#         80624 (0.56%) aligned exactly 1 time
#         48962 (0.34%) aligned >1 times
# 22.87% overall alignment rate
# [INFO] [Feb 12, 2023 17:28:03] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45072.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45072.bam.
# [INFO] [Feb 12, 2023 17:28:26] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45072.sam.
# [INFO] [Feb 12, 2023 17:28:26] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45087.sam
# [INFO] [Feb 12, 2023 17:28:26] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45087_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45087_2.fastq.gz --no-unal -p 12 -k 10
# 8377611 reads; of these:
#   8377611 (100.00%) were paired; of these:
#     6826304 (81.48%) aligned concordantly 0 times
#     1510570 (18.03%) aligned concordantly exactly 1 time
#     40737 (0.49%) aligned concordantly >1 times
#     ----
#     6826304 pairs aligned concordantly 0 times; of these:
#       562221 (8.24%) aligned discordantly 1 time
#     ----
#     6264083 pairs aligned 0 times concordantly or discordantly; of these:
#       12528166 mates make up the pairs; of these:
#         12418012 (99.12%) aligned 0 times
#         69488 (0.55%) aligned exactly 1 time
#         40666 (0.32%) aligned >1 times
# 25.89% overall alignment rate
# [INFO] [Feb 12, 2023 17:30:27] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45087.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45087.bam.
# [INFO] [Feb 12, 2023 17:30:49] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45087.sam.
# [INFO] [Feb 12, 2023 17:30:49] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45092.sam
# [INFO] [Feb 12, 2023 17:30:49] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45092_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45092_2.fastq.gz --no-unal -p 12 -k 10
# 8848058 reads; of these:
#   8848058 (100.00%) were paired; of these:
#     8145615 (92.06%) aligned concordantly 0 times
#     672890 (7.60%) aligned concordantly exactly 1 time
#     29553 (0.33%) aligned concordantly >1 times
#     ----
#     8145615 pairs aligned concordantly 0 times; of these:
#       289439 (3.55%) aligned discordantly 1 time
#     ----
#     7856176 pairs aligned 0 times concordantly or discordantly; of these:
#       15712352 mates make up the pairs; of these:
#         15632064 (99.49%) aligned 0 times
#         40857 (0.26%) aligned exactly 1 time
#         39431 (0.25%) aligned >1 times
# 11.66% overall alignment rate
# [INFO] [Feb 12, 2023 17:32:19] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45092.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45092.bam.
# [INFO] [Feb 12, 2023 17:32:31] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45092.sam.
# [INFO] [Feb 12, 2023 17:32:31] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45100.sam
# [INFO] [Feb 12, 2023 17:32:31] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45100_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45100_2.fastq.gz --no-unal -p 12 -k 10
# 9316170 reads; of these:
#   9316170 (100.00%) were paired; of these:
#     7962016 (85.46%) aligned concordantly 0 times
#     1316607 (14.13%) aligned concordantly exactly 1 time
#     37547 (0.40%) aligned concordantly >1 times
#     ----
#     7962016 pairs aligned concordantly 0 times; of these:
#       839688 (10.55%) aligned discordantly 1 time
#     ----
#     7122328 pairs aligned 0 times concordantly or discordantly; of these:
#       14244656 mates make up the pairs; of these:
#         14113883 (99.08%) aligned 0 times
#         73425 (0.52%) aligned exactly 1 time
#         57348 (0.40%) aligned >1 times
# 24.25% overall alignment rate
# [INFO] [Feb 12, 2023 17:34:32] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45100.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45100.bam.
# [INFO] [Feb 12, 2023 17:34:56] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45100.sam.
# [INFO] [Feb 12, 2023 17:34:56] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45106.sam
# [INFO] [Feb 12, 2023 17:34:56] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45106_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45106_2.fastq.gz --no-unal -p 12 -k 10
# 8312147 reads; of these:
#   8312147 (100.00%) were paired; of these:
#     7692677 (92.55%) aligned concordantly 0 times
#     595760 (7.17%) aligned concordantly exactly 1 time
#     23710 (0.29%) aligned concordantly >1 times
#     ----
#     7692677 pairs aligned concordantly 0 times; of these:
#       242514 (3.15%) aligned discordantly 1 time
#     ----
#     7450163 pairs aligned 0 times concordantly or discordantly; of these:
#       14900326 mates make up the pairs; of these:
#         14835100 (99.56%) aligned 0 times
#         33598 (0.23%) aligned exactly 1 time
#         31628 (0.21%) aligned >1 times
# 10.76% overall alignment rate
# [INFO] [Feb 12, 2023 17:36:18] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45106.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45106.bam.
# [INFO] [Feb 12, 2023 17:36:28] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45106.sam.
# [INFO] [Feb 12, 2023 17:36:28] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45272.sam
# [INFO] [Feb 12, 2023 17:36:28] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45272_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G45272_2.fastq.gz --no-unal -p 12 -k 10
# 11602471 reads; of these:
#   11602471 (100.00%) were paired; of these:
#     10511403 (90.60%) aligned concordantly 0 times
#     1043542 (8.99%) aligned concordantly exactly 1 time
#     47526 (0.41%) aligned concordantly >1 times
#     ----
#     10511403 pairs aligned concordantly 0 times; of these:
#       551350 (5.25%) aligned discordantly 1 time
#     ----
#     9960053 pairs aligned 0 times concordantly or discordantly; of these:
#       19920106 mates make up the pairs; of these:
#         19718527 (98.99%) aligned 0 times
#         135930 (0.68%) aligned exactly 1 time
#         65649 (0.33%) aligned >1 times
# 15.02% overall alignment rate
# [INFO] [Feb 12, 2023 17:38:38] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45272.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45272.bam.
# [INFO] [Feb 12, 2023 17:38:57] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45272.sam.
# [INFO] [Feb 12, 2023 17:38:58] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69166.sam
# [INFO] [Feb 12, 2023 17:38:58] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69166_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69166_2.fastq.gz --no-unal -p 12 -k 10
# 10180750 reads; of these:
#   10180750 (100.00%) were paired; of these:
#     9000612 (88.41%) aligned concordantly 0 times
#     1147648 (11.27%) aligned concordantly exactly 1 time
#     32490 (0.32%) aligned concordantly >1 times
#     ----
#     9000612 pairs aligned concordantly 0 times; of these:
#       973533 (10.82%) aligned discordantly 1 time
#     ----
#     8027079 pairs aligned 0 times concordantly or discordantly; of these:
#       16054158 mates make up the pairs; of these:
#         15910087 (99.10%) aligned 0 times
#         70071 (0.44%) aligned exactly 1 time
#         74000 (0.46%) aligned >1 times
# 21.86% overall alignment rate
# [INFO] [Feb 12, 2023 17:40:59] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69166.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69166.bam.
# [INFO] [Feb 12, 2023 17:41:22] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69166.sam.
# [INFO] [Feb 12, 2023 17:41:22] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69167.sam
# [INFO] [Feb 12, 2023 17:41:22] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69167_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69167_2.fastq.gz --no-unal -p 12 -k 10
# 3878788 reads; of these:
#   3878788 (100.00%) were paired; of these:
#     3308725 (85.30%) aligned concordantly 0 times
#     554244 (14.29%) aligned concordantly exactly 1 time
#     15819 (0.41%) aligned concordantly >1 times
#     ----
#     3308725 pairs aligned concordantly 0 times; of these:
#       376530 (11.38%) aligned discordantly 1 time
#     ----
#     2932195 pairs aligned 0 times concordantly or discordantly; of these:
#       5864390 mates make up the pairs; of these:
#         5805336 (98.99%) aligned 0 times
#         30976 (0.53%) aligned exactly 1 time
#         28078 (0.48%) aligned >1 times
# 25.17% overall alignment rate
# [INFO] [Feb 12, 2023 17:42:10] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69167.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69167.bam.
# [INFO] [Feb 12, 2023 17:42:20] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69167.sam.
# [INFO] [Feb 12, 2023 17:42:20] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69178.sam
# [INFO] [Feb 12, 2023 17:42:20] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69178_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69178_2.fastq.gz --no-unal -p 12 -k 10
# 5811733 reads; of these:
#   5811733 (100.00%) were paired; of these:
#     4627923 (79.63%) aligned concordantly 0 times
#     1155267 (19.88%) aligned concordantly exactly 1 time
#     28543 (0.49%) aligned concordantly >1 times
#     ----
#     4627923 pairs aligned concordantly 0 times; of these:
#       574136 (12.41%) aligned discordantly 1 time
#     ----
#     4053787 pairs aligned 0 times concordantly or discordantly; of these:
#       8107574 mates make up the pairs; of these:
#         8019281 (98.91%) aligned 0 times
#         49445 (0.61%) aligned exactly 1 time
#         38848 (0.48%) aligned >1 times
# 31.01% overall alignment rate
# [INFO] [Feb 12, 2023 17:43:42] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69178.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69178.bam.
# [INFO] [Feb 12, 2023 17:44:00] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69178.sam.
# [INFO] [Feb 12, 2023 17:44:01] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69187.sam
# [INFO] [Feb 12, 2023 17:44:01] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69187_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69187_2.fastq.gz --no-unal -p 12 -k 10
# 5345938 reads; of these:
#   5345938 (100.00%) were paired; of these:
#     4800198 (89.79%) aligned concordantly 0 times
#     534875 (10.01%) aligned concordantly exactly 1 time
#     10865 (0.20%) aligned concordantly >1 times
#     ----
#     4800198 pairs aligned concordantly 0 times; of these:
#       1705466 (35.53%) aligned discordantly 1 time
#     ----
#     3094732 pairs aligned 0 times concordantly or discordantly; of these:
#       6189464 mates make up the pairs; of these:
#         6074398 (98.14%) aligned 0 times
#         38766 (0.63%) aligned exactly 1 time
#         76300 (1.23%) aligned >1 times
# 43.19% overall alignment rate
# [INFO] [Feb 12, 2023 17:45:21] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69187.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69187.bam.
# [INFO] [Feb 12, 2023 17:45:44] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69187.sam.
# [INFO] [Feb 12, 2023 17:45:44] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69192.sam
# [INFO] [Feb 12, 2023 17:45:44] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69192_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69192_2.fastq.gz --no-unal -p 12 -k 10
# 6218700 reads; of these:
#   6218700 (100.00%) were paired; of these:
#     4539293 (72.99%) aligned concordantly 0 times
#     1644583 (26.45%) aligned concordantly exactly 1 time
#     34824 (0.56%) aligned concordantly >1 times
#     ----
#     4539293 pairs aligned concordantly 0 times; of these:
#       1006595 (22.18%) aligned discordantly 1 time
#     ----
#     3532698 pairs aligned 0 times concordantly or discordantly; of these:
#       7065396 mates make up the pairs; of these:
#         6947779 (98.34%) aligned 0 times
#         63289 (0.90%) aligned exactly 1 time
#         54328 (0.77%) aligned >1 times
# 44.14% overall alignment rate
# [INFO] [Feb 12, 2023 17:47:29] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69192.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69192.bam.
# [INFO] [Feb 12, 2023 17:47:55] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69192.sam.
# [INFO] [Feb 12, 2023 17:47:56] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69193.sam
# [INFO] [Feb 12, 2023 17:47:56] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69193_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69193_2.fastq.gz --no-unal -p 12 -k 10
# 9495589 reads; of these:
#   9495589 (100.00%) were paired; of these:
#     7592814 (79.96%) aligned concordantly 0 times
#     1859817 (19.59%) aligned concordantly exactly 1 time
#     42958 (0.45%) aligned concordantly >1 times
#     ----
#     7592814 pairs aligned concordantly 0 times; of these:
#       1238407 (16.31%) aligned discordantly 1 time
#     ----
#     6354407 pairs aligned 0 times concordantly or discordantly; of these:
#       12708814 mates make up the pairs; of these:
#         12565920 (98.88%) aligned 0 times
#         67264 (0.53%) aligned exactly 1 time
#         75630 (0.60%) aligned >1 times
# 33.83% overall alignment rate
# [INFO] [Feb 12, 2023 17:50:16] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69193.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69193.bam.
# [INFO] [Feb 12, 2023 17:50:50] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69193.sam.
# [INFO] [Feb 12, 2023 17:50:51] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69206.sam
# [INFO] [Feb 12, 2023 17:50:51] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69206_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69206_2.fastq.gz --no-unal -p 12 -k 10
# 12270709 reads; of these:
#   12270709 (100.00%) were paired; of these:
#     10723332 (87.39%) aligned concordantly 0 times
#     1507043 (12.28%) aligned concordantly exactly 1 time
#     40334 (0.33%) aligned concordantly >1 times
#     ----
#     10723332 pairs aligned concordantly 0 times; of these:
#       1008820 (9.41%) aligned discordantly 1 time
#     ----
#     9714512 pairs aligned 0 times concordantly or discordantly; of these:
#       19429024 mates make up the pairs; of these:
#         19285549 (99.26%) aligned 0 times
#         71540 (0.37%) aligned exactly 1 time
#         71935 (0.37%) aligned >1 times
# 21.42% overall alignment rate
# [INFO] [Feb 12, 2023 17:53:20] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69206.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69206.bam.
# [INFO] [Feb 12, 2023 17:53:47] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69206.sam.
# [INFO] [Feb 12, 2023 17:53:48] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69211.sam
# [INFO] [Feb 12, 2023 17:53:48] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69211_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69211_2.fastq.gz --no-unal -p 12 -k 10
# 6435454 reads; of these:
#   6435454 (100.00%) were paired; of these:
#     5094555 (79.16%) aligned concordantly 0 times
#     1314007 (20.42%) aligned concordantly exactly 1 time
#     26892 (0.42%) aligned concordantly >1 times
#     ----
#     5094555 pairs aligned concordantly 0 times; of these:
#       758759 (14.89%) aligned discordantly 1 time
#     ----
#     4335796 pairs aligned 0 times concordantly or discordantly; of these:
#       8671592 mates make up the pairs; of these:
#         8603288 (99.21%) aligned 0 times
#         27532 (0.32%) aligned exactly 1 time
#         40772 (0.47%) aligned >1 times
# 33.16% overall alignment rate
# [INFO] [Feb 12, 2023 17:55:20] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69211.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69211.bam.
# [INFO] [Feb 12, 2023 17:55:40] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69211.sam.
# [INFO] [Feb 12, 2023 17:55:40] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69212.sam
# [INFO] [Feb 12, 2023 17:55:40] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69212_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69212_2.fastq.gz --no-unal -p 12 -k 10
# 3377170 reads; of these:
#   3377170 (100.00%) were paired; of these:
#     2646986 (78.38%) aligned concordantly 0 times
#     714994 (21.17%) aligned concordantly exactly 1 time
#     15190 (0.45%) aligned concordantly >1 times
#     ----
#     2646986 pairs aligned concordantly 0 times; of these:
#       690559 (26.09%) aligned discordantly 1 time
#     ----
#     1956427 pairs aligned 0 times concordantly or discordantly; of these:
#       3912854 mates make up the pairs; of these:
#         3861421 (98.69%) aligned 0 times
#         16363 (0.42%) aligned exactly 1 time
#         35070 (0.90%) aligned >1 times
# 42.83% overall alignment rate
# [INFO] [Feb 12, 2023 17:56:35] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69212.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69212.bam.
# [INFO] [Feb 12, 2023 17:56:49] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69212.sam.
# [INFO] [Feb 12, 2023 17:56:49] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69227.sam
# [INFO] [Feb 12, 2023 17:56:49] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69227_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G69227_2.fastq.gz --no-unal -p 12 -k 10
# 12500195 reads; of these:
#   12500195 (100.00%) were paired; of these:
#     8914885 (71.32%) aligned concordantly 0 times
#     3506032 (28.05%) aligned concordantly exactly 1 time
#     79278 (0.63%) aligned concordantly >1 times
#     ----
#     8914885 pairs aligned concordantly 0 times; of these:
#       1226506 (13.76%) aligned discordantly 1 time
#     ----
#     7688379 pairs aligned 0 times concordantly or discordantly; of these:
#       15376758 mates make up the pairs; of these:
#         15136064 (98.43%) aligned 0 times
#         168536 (1.10%) aligned exactly 1 time
#         72158 (0.47%) aligned >1 times
# 39.46% overall alignment rate
# [INFO] [Feb 12, 2023 18:00:18] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69227.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69227.bam.
# [INFO] [Feb 12, 2023 18:01:08] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69227.sam.
# [INFO] [Feb 12, 2023 18:01:08] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78487.sam
# [INFO] [Feb 12, 2023 18:01:08] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78487_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78487_2.fastq.gz --no-unal -p 12 -k 10
# 3211100 reads; of these:
#   3211100 (100.00%) were paired; of these:
#     2788473 (86.84%) aligned concordantly 0 times
#     411901 (12.83%) aligned concordantly exactly 1 time
#     10726 (0.33%) aligned concordantly >1 times
#     ----
#     2788473 pairs aligned concordantly 0 times; of these:
#       115789 (4.15%) aligned discordantly 1 time
#     ----
#     2672684 pairs aligned 0 times concordantly or discordantly; of these:
#       5345368 mates make up the pairs; of these:
#         5312077 (99.38%) aligned 0 times
#         22839 (0.43%) aligned exactly 1 time
#         10452 (0.20%) aligned >1 times
# 17.29% overall alignment rate
# [INFO] [Feb 12, 2023 18:01:43] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78487.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78487.bam.
# [INFO] [Feb 12, 2023 18:01:50] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78487.sam.
# [INFO] [Feb 12, 2023 18:01:50] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78494.sam
# [INFO] [Feb 12, 2023 18:01:50] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78494_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78494_2.fastq.gz --no-unal -p 12 -k 10
# 2609279 reads; of these:
#   2609279 (100.00%) were paired; of these:
#     2380549 (91.23%) aligned concordantly 0 times
#     221945 (8.51%) aligned concordantly exactly 1 time
#     6785 (0.26%) aligned concordantly >1 times
#     ----
#     2380549 pairs aligned concordantly 0 times; of these:
#       75835 (3.19%) aligned discordantly 1 time
#     ----
#     2304714 pairs aligned 0 times concordantly or discordantly; of these:
#       4609428 mates make up the pairs; of these:
#         4583099 (99.43%) aligned 0 times
#         18691 (0.41%) aligned exactly 1 time
#         7638 (0.17%) aligned >1 times
# 12.18% overall alignment rate
# [INFO] [Feb 12, 2023 18:02:15] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78494.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78494.bam.
# [INFO] [Feb 12, 2023 18:02:19] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78494.sam.
# [INFO] [Feb 12, 2023 18:02:20] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78509.sam
# [INFO] [Feb 12, 2023 18:02:20] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78509_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78509_2.fastq.gz --no-unal -p 12 -k 10
# 7717047 reads; of these:
#   7717047 (100.00%) were paired; of these:
#     6877207 (89.12%) aligned concordantly 0 times
#     817212 (10.59%) aligned concordantly exactly 1 time
#     22628 (0.29%) aligned concordantly >1 times
#     ----
#     6877207 pairs aligned concordantly 0 times; of these:
#       295104 (4.29%) aligned discordantly 1 time
#     ----
#     6582103 pairs aligned 0 times concordantly or discordantly; of these:
#       13164206 mates make up the pairs; of these:
#         13096737 (99.49%) aligned 0 times
#         39779 (0.30%) aligned exactly 1 time
#         27690 (0.21%) aligned >1 times
# 15.14% overall alignment rate
# [INFO] [Feb 12, 2023 18:03:44] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78509.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78509.bam.
# [INFO] [Feb 12, 2023 18:03:58] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78509.sam.
# [INFO] [Feb 12, 2023 18:03:58] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78517.sam
# [INFO] [Feb 12, 2023 18:03:58] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78517_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78517_2.fastq.gz --no-unal -p 12 -k 10
# 4289906 reads; of these:
#   4289906 (100.00%) were paired; of these:
#     3146942 (73.36%) aligned concordantly 0 times
#     1120385 (26.12%) aligned concordantly exactly 1 time
#     22579 (0.53%) aligned concordantly >1 times
#     ----
#     3146942 pairs aligned concordantly 0 times; of these:
#       292617 (9.30%) aligned discordantly 1 time
#     ----
#     2854325 pairs aligned 0 times concordantly or discordantly; of these:
#       5708650 mates make up the pairs; of these:
#         5648834 (98.95%) aligned 0 times
#         42315 (0.74%) aligned exactly 1 time
#         17501 (0.31%) aligned >1 times
# 34.16% overall alignment rate
# [INFO] [Feb 12, 2023 18:05:03] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78517.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78517.bam.
# [INFO] [Feb 12, 2023 18:05:18] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78517.sam.
# [INFO] [Feb 12, 2023 18:05:18] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78528.sam
# [INFO] [Feb 12, 2023 18:05:18] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78528_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78528_2.fastq.gz --no-unal -p 12 -k 10
# 4756615 reads; of these:
#   4756615 (100.00%) were paired; of these:
#     3756776 (78.98%) aligned concordantly 0 times
#     977873 (20.56%) aligned concordantly exactly 1 time
#     21966 (0.46%) aligned concordantly >1 times
#     ----
#     3756776 pairs aligned concordantly 0 times; of these:
#       178699 (4.76%) aligned discordantly 1 time
#     ----
#     3578077 pairs aligned 0 times concordantly or discordantly; of these:
#       7156154 mates make up the pairs; of these:
#         7096325 (99.16%) aligned 0 times
#         45376 (0.63%) aligned exactly 1 time
#         14453 (0.20%) aligned >1 times
# 25.41% overall alignment rate
# [INFO] [Feb 12, 2023 18:06:21] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78528.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78528.bam.
# [INFO] [Feb 12, 2023 18:06:33] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78528.sam.
# [INFO] [Feb 12, 2023 18:06:33] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78541.sam
# [INFO] [Feb 12, 2023 18:06:33] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78541_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78541_2.fastq.gz --no-unal -p 12 -k 10
# 6296118 reads; of these:
#   6296118 (100.00%) were paired; of these:
#     5070023 (80.53%) aligned concordantly 0 times
#     1198197 (19.03%) aligned concordantly exactly 1 time
#     27898 (0.44%) aligned concordantly >1 times
#     ----
#     5070023 pairs aligned concordantly 0 times; of these:
#       801884 (15.82%) aligned discordantly 1 time
#     ----
#     4268139 pairs aligned 0 times concordantly or discordantly; of these:
#       8536278 mates make up the pairs; of these:
#         8426328 (98.71%) aligned 0 times
#         62891 (0.74%) aligned exactly 1 time
#         47059 (0.55%) aligned >1 times
# 33.08% overall alignment rate
# [INFO] [Feb 12, 2023 18:08:05] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78541.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78541.bam.
# [INFO] [Feb 12, 2023 18:08:27] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78541.sam.
# [INFO] [Feb 12, 2023 18:08:27] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78554.sam
# [INFO] [Feb 12, 2023 18:08:27] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78554_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78554_2.fastq.gz --no-unal -p 12 -k 10
# 2669923 reads; of these:
#   2669923 (100.00%) were paired; of these:
#     2288379 (85.71%) aligned concordantly 0 times
#     369339 (13.83%) aligned concordantly exactly 1 time
#     12205 (0.46%) aligned concordantly >1 times
#     ----
#     2288379 pairs aligned concordantly 0 times; of these:
#       125471 (5.48%) aligned discordantly 1 time
#     ----
#     2162908 pairs aligned 0 times concordantly or discordantly; of these:
#       4325816 mates make up the pairs; of these:
#         4268316 (98.67%) aligned 0 times
#         46130 (1.07%) aligned exactly 1 time
#         11370 (0.26%) aligned >1 times
# 20.07% overall alignment rate
# [INFO] [Feb 12, 2023 18:08:57] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78554.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78554.bam.
# [INFO] [Feb 12, 2023 18:09:03] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78554.sam.
# [INFO] [Feb 12, 2023 18:09:03] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78627.sam
# [INFO] [Feb 12, 2023 18:09:03] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78627_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78627_2.fastq.gz --no-unal -p 12 -k 10
# 2817973 reads; of these:
#   2817973 (100.00%) were paired; of these:
#     2626324 (93.20%) aligned concordantly 0 times
#     184232 (6.54%) aligned concordantly exactly 1 time
#     7417 (0.26%) aligned concordantly >1 times
#     ----
#     2626324 pairs aligned concordantly 0 times; of these:
#       54077 (2.06%) aligned discordantly 1 time
#     ----
#     2572247 pairs aligned 0 times concordantly or discordantly; of these:
#       5144494 mates make up the pairs; of these:
#         5112458 (99.38%) aligned 0 times
#         23369 (0.45%) aligned exactly 1 time
#         8667 (0.17%) aligned >1 times
# 9.29% overall alignment rate
# [INFO] [Feb 12, 2023 18:09:29] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78627.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78627.bam.
# [INFO] [Feb 12, 2023 18:09:32] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78627.sam.
# [INFO] [Feb 12, 2023 18:09:33] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78655.sam
# [INFO] [Feb 12, 2023 18:09:33] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78655_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78655_2.fastq.gz --no-unal -p 12 -k 10
# 5001703 reads; of these:
#   5001703 (100.00%) were paired; of these:
#     4515669 (90.28%) aligned concordantly 0 times
#     469747 (9.39%) aligned concordantly exactly 1 time
#     16287 (0.33%) aligned concordantly >1 times
#     ----
#     4515669 pairs aligned concordantly 0 times; of these:
#       326741 (7.24%) aligned discordantly 1 time
#     ----
#     4188928 pairs aligned 0 times concordantly or discordantly; of these:
#       8377856 mates make up the pairs; of these:
#         8320675 (99.32%) aligned 0 times
#         25549 (0.30%) aligned exactly 1 time
#         31632 (0.38%) aligned >1 times
# 16.82% overall alignment rate
# [INFO] [Feb 12, 2023 18:10:29] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78655.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78655.bam.
# [INFO] [Feb 12, 2023 18:10:39] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78655.sam.
# [INFO] [Feb 12, 2023 18:10:39] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78714.sam
# [INFO] [Feb 12, 2023 18:10:39] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78714_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78714_2.fastq.gz --no-unal -p 12 -k 10
# 7085374 reads; of these:
#   7085374 (100.00%) were paired; of these:
#     6772862 (95.59%) aligned concordantly 0 times
#     292867 (4.13%) aligned concordantly exactly 1 time
#     19645 (0.28%) aligned concordantly >1 times
#     ----
#     6772862 pairs aligned concordantly 0 times; of these:
#       70046 (1.03%) aligned discordantly 1 time
#     ----
#     6702816 pairs aligned 0 times concordantly or discordantly; of these:
#       13405632 mates make up the pairs; of these:
#         13350697 (99.59%) aligned 0 times
#         33902 (0.25%) aligned exactly 1 time
#         21033 (0.16%) aligned >1 times
# 5.79% overall alignment rate
# [INFO] [Feb 12, 2023 18:11:42] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78714.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78714.bam.
# [INFO] [Feb 12, 2023 18:11:47] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78714.sam.
# [INFO] [Feb 12, 2023 18:11:47] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78717.sam
# [INFO] [Feb 12, 2023 18:11:47] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78717_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78717_2.fastq.gz --no-unal -p 12 -k 10
# 3677056 reads; of these:
#   3677056 (100.00%) were paired; of these:
#     3230967 (87.87%) aligned concordantly 0 times
#     433232 (11.78%) aligned concordantly exactly 1 time
#     12857 (0.35%) aligned concordantly >1 times
#     ----
#     3230967 pairs aligned concordantly 0 times; of these:
#       123586 (3.83%) aligned discordantly 1 time
#     ----
#     3107381 pairs aligned 0 times concordantly or discordantly; of these:
#       6214762 mates make up the pairs; of these:
#         6178079 (99.41%) aligned 0 times
#         24304 (0.39%) aligned exactly 1 time
#         12379 (0.20%) aligned >1 times
# 15.99% overall alignment rate
# [INFO] [Feb 12, 2023 18:12:27] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78717.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78717.bam.
# [INFO] [Feb 12, 2023 18:12:34] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78717.sam.
# [INFO] [Feb 12, 2023 18:12:34] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78718.sam
# [INFO] [Feb 12, 2023 18:12:34] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78718_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78718_2.fastq.gz --no-unal -p 12 -k 10
# 8329356 reads; of these:
#   8329356 (100.00%) were paired; of these:
#     8003515 (96.09%) aligned concordantly 0 times
#     307667 (3.69%) aligned concordantly exactly 1 time
#     18174 (0.22%) aligned concordantly >1 times
#     ----
#     8003515 pairs aligned concordantly 0 times; of these:
#       106861 (1.34%) aligned discordantly 1 time
#     ----
#     7896654 pairs aligned 0 times concordantly or discordantly; of these:
#       15793308 mates make up the pairs; of these:
#         15736526 (99.64%) aligned 0 times
#         30661 (0.19%) aligned exactly 1 time
#         26121 (0.17%) aligned >1 times
# 5.54% overall alignment rate
# [INFO] [Feb 12, 2023 18:13:47] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78718.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78718.bam.
# [INFO] [Feb 12, 2023 18:13:52] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78718.sam.
# [INFO] [Feb 12, 2023 18:13:52] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78719.sam
# [INFO] [Feb 12, 2023 18:13:52] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78719_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78719_2.fastq.gz --no-unal -p 12 -k 10
# 4112392 reads; of these:
#   4112392 (100.00%) were paired; of these:
#     4075155 (99.09%) aligned concordantly 0 times
#     28422 (0.69%) aligned concordantly exactly 1 time
#     8815 (0.21%) aligned concordantly >1 times
#     ----
#     4075155 pairs aligned concordantly 0 times; of these:
#       6461 (0.16%) aligned discordantly 1 time
#     ----
#     4068694 pairs aligned 0 times concordantly or discordantly; of these:
#       8137388 mates make up the pairs; of these:
#         8117391 (99.75%) aligned 0 times
#         10314 (0.13%) aligned exactly 1 time
#         9683 (0.12%) aligned >1 times
# 1.31% overall alignment rate
# [INFO] [Feb 12, 2023 18:14:25] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78719.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78719.bam.
# [INFO] [Feb 12, 2023 18:14:26] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78719.sam.
# [INFO] [Feb 12, 2023 18:14:26] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78728.sam
# [INFO] [Feb 12, 2023 18:14:26] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78728_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78728_2.fastq.gz --no-unal -p 12 -k 10
# 3266950 reads; of these:
#   3266950 (100.00%) were paired; of these:
#     3085388 (94.44%) aligned concordantly 0 times
#     176992 (5.42%) aligned concordantly exactly 1 time
#     4570 (0.14%) aligned concordantly >1 times
#     ----
#     3085388 pairs aligned concordantly 0 times; of these:
#       437442 (14.18%) aligned discordantly 1 time
#     ----
#     2647946 pairs aligned 0 times concordantly or discordantly; of these:
#       5295892 mates make up the pairs; of these:
#         5255156 (99.23%) aligned 0 times
#         12651 (0.24%) aligned exactly 1 time
#         28085 (0.53%) aligned >1 times
# 19.57% overall alignment rate
# [INFO] [Feb 12, 2023 18:15:02] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78728.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78728.bam.
# [INFO] [Feb 12, 2023 18:15:10] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78728.sam.
# [INFO] [Feb 12, 2023 18:15:10] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78734.sam
# [INFO] [Feb 12, 2023 18:15:10] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78734_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G78734_2.fastq.gz --no-unal -p 12 -k 10
# 2383975 reads; of these:
#   2383975 (100.00%) were paired; of these:
#     1765172 (74.04%) aligned concordantly 0 times
#     603686 (25.32%) aligned concordantly exactly 1 time
#     15117 (0.63%) aligned concordantly >1 times
#     ----
#     1765172 pairs aligned concordantly 0 times; of these:
#       233961 (13.25%) aligned discordantly 1 time
#     ----
#     1531211 pairs aligned 0 times concordantly or discordantly; of these:
#       3062422 mates make up the pairs; of these:
#         3010604 (98.31%) aligned 0 times
#         35318 (1.15%) aligned exactly 1 time
#         16500 (0.54%) aligned >1 times
# 36.86% overall alignment rate
# [INFO] [Feb 12, 2023 18:15:49] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78734.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78734.bam.
# [INFO] [Feb 12, 2023 18:15:59] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78734.sam.
# ...
# [INFO] [Feb 12, 2023 19:12:03] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80530.sam.
# [INFO] [Feb 12, 2023 19:12:03] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80535.sam
# [INFO] [Feb 12, 2023 19:12:03] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G80535_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G80535_2.fastq.gz --no-unal -p 12 -k 10
# 6199572 reads; of these:
#   6199572 (100.00%) were paired; of these:
#     4525960 (73.00%) aligned concordantly 0 times
#     1637705 (26.42%) aligned concordantly exactly 1 time
#     35907 (0.58%) aligned concordantly >1 times
#     ----
#     4525960 pairs aligned concordantly 0 times; of these:
#       653513 (14.44%) aligned discordantly 1 time
#     ----
#     3872447 pairs aligned 0 times concordantly or discordantly; of these:
#       7744894 mates make up the pairs; of these:
#         7641800 (98.67%) aligned 0 times
#         67445 (0.87%) aligned exactly 1 time
#         35649 (0.46%) aligned >1 times
# 38.37% overall alignment rate
# [INFO] [Feb 12, 2023 19:13:47] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80535.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80535.bam.
# [INFO] [Feb 12, 2023 19:14:12] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80535.sam.
# [INFO] [Feb 12, 2023 19:14:12] [coptr.read_mapper] Mapping /home/phil/DATA/diabimmune/wgs_aptr/reads to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80621.sam
# [INFO] [Feb 12, 2023 19:14:12] [coptr.read_mapper] bowtie2 -x /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/index/seqs -1 /home/phil/DATA/diabimmune/wgs_aptr/reads/G80621_1.fastq.gz -2 /home/phil/DATA/diabimmune/wgs_aptr/reads/G80621_2.fastq.gz --no-unal -p 12 -k 10
# 2380058 reads; of these:
#   2380058 (100.00%) were paired; of these:
#     1923303 (80.81%) aligned concordantly 0 times
#     443761 (18.64%) aligned concordantly exactly 1 time
#     12994 (0.55%) aligned concordantly >1 times
#     ----
#     1923303 pairs aligned concordantly 0 times; of these:
#       105448 (5.48%) aligned discordantly 1 time
#     ----
#     1817855 pairs aligned 0 times concordantly or discordantly; of these:
#       3635710 mates make up the pairs; of these:
#         3562167 (97.98%) aligned 0 times
#         64721 (1.78%) aligned exactly 1 time
#         8822 (0.24%) aligned >1 times
# 25.17% overall alignment rate
# [INFO] [Feb 12, 2023 19:14:43] [coptr.read_mapper] Converting /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80621.sam to /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80621.bam.
# [INFO] [Feb 12, 2023 19:14:50] [coptr.read_mapper] Cleaning up /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G80621.sam.
# [INFO] [Feb 12, 2023 19:15:03] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45050.bam.
# [INFO] [Feb 12, 2023 19:15:09] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:15:14] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:15:23] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:15:27] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:15:28] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45054.bam.
# [INFO] [Feb 12, 2023 19:15:35] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:15:44] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:16:00] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:16:09] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:16:09] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45056.bam.
# [INFO] [Feb 12, 2023 19:16:24] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:16:41] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:17:13] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:17:30] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:17:30] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45067.bam.
# [INFO] [Feb 12, 2023 19:17:34] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:17:40] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:17:49] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:17:54] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:17:54] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45072.bam.
# [INFO] [Feb 12, 2023 19:18:09] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:18:28] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:19:02] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:19:20] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:19:20] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45087.bam.
# [INFO] [Feb 12, 2023 19:19:36] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:19:56] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:20:32] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:20:51] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:20:51] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45092.bam.
# [INFO] [Feb 12, 2023 19:21:00] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:21:11] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:21:40] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:21:41] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45100.bam.
# [INFO] [Feb 12, 2023 19:21:57] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:22:17] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:22:54] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:23:13] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:23:13] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45106.bam.
# [INFO] [Feb 12, 2023 19:23:20] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:23:30] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:23:46] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:23:55] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:23:56] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G45272.bam.
# [INFO] [Feb 12, 2023 19:24:09] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:24:23] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:24:49] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:25:02] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:25:02] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69166.bam.
# [INFO] [Feb 12, 2023 19:25:18] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:25:38] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:26:15] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:26:34] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:26:34] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69167.bam.
# [INFO] [Feb 12, 2023 19:26:41] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:26:52] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:27:10] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:27:20] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:27:20] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69178.bam.
# [INFO] [Feb 12, 2023 19:27:33] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:27:49] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:28:19] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:28:35] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:28:35] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69187.bam.
# [INFO] [Feb 12, 2023 19:28:50] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:29:10] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:29:49] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:30:09] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:30:09] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69192.bam.
# [INFO] [Feb 12, 2023 19:30:27] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:30:53] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:31:39] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:32:03] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:32:03] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69193.bam.
# [INFO] [Feb 12, 2023 19:32:26] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:32:55] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:33:50] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:34:18] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:34:18] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69206.bam.
# [INFO] [Feb 12, 2023 19:34:37] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:35:02] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:35:49] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:36:14] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:36:15] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69211.bam.
# [INFO] [Feb 12, 2023 19:36:29] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:36:48] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:37:24] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:37:43] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:37:43] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69212.bam.
# [INFO] [Feb 12, 2023 19:37:53] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:38:07] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:38:32] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:38:45] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:38:45] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G69227.bam.
# [INFO] [Feb 12, 2023 19:39:18] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:40:02] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:41:23] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:42:05] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:42:06] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78487.bam.
# [INFO] [Feb 12, 2023 19:42:10] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:42:16] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:42:26] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:42:32] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:42:32] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78494.bam.
# [INFO] [Feb 12, 2023 19:42:34] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:42:37] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:42:43] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:42:46] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:42:47] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78509.bam.
# [INFO] [Feb 12, 2023 19:42:55] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:43:06] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:43:25] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:43:34] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:43:34] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78517.bam.
# [INFO] [Feb 12, 2023 19:43:45] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:43:58] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:44:22] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:44:34] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:44:34] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78528.bam.
# [INFO] [Feb 12, 2023 19:44:43] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:44:54] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:45:14] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:45:24] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:45:24] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78541.bam.
# [INFO] [Feb 12, 2023 19:45:38] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:45:57] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:46:30] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:46:48] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:46:48] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78554.bam.
# [INFO] [Feb 12, 2023 19:46:52] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:46:57] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:47:11] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:47:12] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78627.bam.
# [INFO] [Feb 12, 2023 19:47:13] [coptr.bam_processor] Determining reference genomes.
# [INFO] [Feb 12, 2023 19:47:16] [coptr.bam_processor] Collecting multi-mapped reads.
# [INFO] [Feb 12, 2023 19:47:20] [coptr.bam_processor] Assigning multi-mapped reads.
# [INFO] [Feb 12, 2023 19:47:23] [coptr.bam_processor] Grouping reads by reference genome.
# [INFO] [Feb 12, 2023 19:47:23] [coptr.bam_processor] Processing /home/phil/DATA/diabimmune/wgs_aptr/coptr_out/bam/G78655.bam.
