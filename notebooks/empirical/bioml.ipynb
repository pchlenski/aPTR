# %%
import pandas as pd

# %%
# That didn't work super well, let's try to parse the XML manually

import xml.etree.ElementTree as ET

tree = ET.parse("../../data/bioml/sra_metadata.xml")
root = tree.getroot()
root
# Out:
# <Element 'BioSampleSet' at 0x7f39f9a84db0>

# %%
# Find all the BioSample elements
biosamples = root.findall(".//BioSample")

# Create a dictionary to store the IDs for each sample
sample_ids = {}

# Iterate over each BioSample element
for biosample in biosamples:
    # Get the sample accession
    accession = biosample.get("accession")
    # print(accession)

    # Find all the Id elements within the BioSample
    ids = biosample.findall(".//Id")

    # Create a dictionary to store the IDs for the current sample
    sample_ids[accession] = {}

    # Iterate over each Id element and extract the ID values
    for id_elem in ids:
        id_value = id_elem.text
        if "db" in id_elem.attrib:
            db = id_elem.get("db")
        elif "db_label" in id_elem.attrib:
            db = id_elem.get("db_label")
        else:
            db = "unknown"
        sample_ids[accession][db] = id_value
    # break

# Print the extracted IDs for each sample
for accession, ids in sample_ids.items():
    print(f"Sample Accession: {accession}")
    for db, id_value in ids.items():
        print(f"  {db}: {id_value}")
    print()
# Out:
# Sample Accession: SAMN11950562
#   BioSample: SAMN11950562
#   Sample name: dl-0006_MG
#   SRA: SRS4899508
#
# Sample Accession: SAMN11950561
#   BioSample: SAMN11950561
#   Sample name: dl-0001_MG
#   SRA: SRS4899507
#
# Sample Accession: SAMN11950560
#   BioSample: SAMN11950560
#   Sample name: dk-0003_MG
#   SRA: SRS4899944
#
# Sample Accession: SAMN11950559
#   BioSample: SAMN11950559
#   Sample name: dk-0001_MG
#   SRA: SRS4899890
#
# Sample Accession: SAMN11950558
#   BioSample: SAMN11950558
#   Sample name: dj-0016_MG
#   SRA: SRS4899891
#
# Sample Accession: SAMN11950557
#   BioSample: SAMN11950557
#   Sample name: dj-0001_MG
#   SRA: SRS4899896
#
# Sample Accession: SAMN11950556
#   BioSample: SAMN11950556
#   Sample name: di-0009_MG
#   SRA: SRS4899555
#
# Sample Accession: SAMN11950555
#   BioSample: SAMN11950555
#   Sample name: di-0001_MG
#   SRA: SRS4899894
#
# Sample Accession: SAMN11950554
#   BioSample: SAMN11950554
#   Sample name: dh-0010_MG
#   SRA: SRS4899895
#
# Sample Accession: SAMN11950553
#   BioSample: SAMN11950553
#   Sample name: dh-0001_MG
#   SRA: SRS4899901
#
# Sample Accession: SAMN11950552
#   BioSample: SAMN11950552
#   Sample name: dg-0008_MG
#   SRA: SRS4899566
#
# Sample Accession: SAMN11950551
#   BioSample: SAMN11950551
#   Sample name: dg-0001_MG
#   SRA: SRS4899897
#
# Sample Accession: SAMN11950550
#   BioSample: SAMN11950550
#   Sample name: df-0030_MG
#   SRA: SRS4899900
#
# Sample Accession: SAMN11950549
#   BioSample: SAMN11950549
#   Sample name: df-0001_MG
#   SRA: SRS4899719
#
# Sample Accession: SAMN11950548
#   BioSample: SAMN11950548
#   Sample name: de-0031_MG
#   SRA: SRS4899716
#
# Sample Accession: SAMN11950547
#   BioSample: SAMN11950547
#   Sample name: de-0001_MG
#   SRA: SRS4899711
#
# Sample Accession: SAMN11950546
#   BioSample: SAMN11950546
#   Sample name: dd-0041_MG
#   SRA: SRS4899710
#
# Sample Accession: SAMN11950545
#   BioSample: SAMN11950545
#   Sample name: dd-0001_MG
#   SRA: SRS4899713
#
# Sample Accession: SAMN11950544
#   BioSample: SAMN11950544
#   Sample name: dc-0028_MG
#   SRA: SRS4899712
#
# Sample Accession: SAMN11950543
#   BioSample: SAMN11950543
#   Sample name: dc-0001_MG
#   SRA: SRS4899715
#
# Sample Accession: SAMN11950542
#   BioSample: SAMN11950542
#   Sample name: db-0015_MG
#   SRA: SRS4899714
#
# Sample Accession: SAMN11950541
#   BioSample: SAMN11950541
#   Sample name: db-0001_MG
#   SRA: SRS4899733
#
# Sample Accession: SAMN11950540
#   BioSample: SAMN11950540
#   Sample name: da-0044_MG
#   SRA: SRS4899731
#
# Sample Accession: SAMN11950539
#   BioSample: SAMN11950539
#   Sample name: da-0001_MG
#   SRA: SRS4899722
#
# Sample Accession: SAMN11950538
#   BioSample: SAMN11950538
#   Sample name: cz-0039_MG
#   SRA: SRS4899721
#
# Sample Accession: SAMN11950537
#   BioSample: SAMN11950537
#   Sample name: cz-0001_MG
#   SRA: SRS4899726
#
# Sample Accession: SAMN11950536
#   BioSample: SAMN11950536
#   Sample name: cy-0037_MG
#   SRA: SRS4899728
#
# Sample Accession: SAMN11950535
#   BioSample: SAMN11950535
#   Sample name: cy-0019_MG
#   SRA: SRS4899730
#
# Sample Accession: SAMN11950534
#   BioSample: SAMN11950534
#   Sample name: cy-0001_MG
#   SRA: SRS4899729
#
# Sample Accession: SAMN11950533
#   BioSample: SAMN11950533
#   Sample name: cx-0014_MG
#   SRA: SRS4899723
#
# Sample Accession: SAMN11950532
#   BioSample: SAMN11950532
#   Sample name: cx-0001_MG
#   SRA: SRS4899724
#
# Sample Accession: SAMN11950531
#   BioSample: SAMN11950531
#   Sample name: cw-0053_MG
#   SRA: SRS4899725
#
# Sample Accession: SAMN11950530
#   BioSample: SAMN11950530
#   Sample name: cw-0035_MG
#   SRA: SRS4899727
#
# Sample Accession: SAMN11950529
#   BioSample: SAMN11950529
#   Sample name: cw-0001_MG
#   SRA: SRS4899570
#
# Sample Accession: SAMN11950528
#   BioSample: SAMN11950528
#   Sample name: cv-0018_MG
#   SRA: SRS4899569
#
# Sample Accession: SAMN11950527
#   BioSample: SAMN11950527
#   Sample name: cv-0001_MG
#   SRA: SRS4899577
#
# Sample Accession: SAMN11950526
#   BioSample: SAMN11950526
#   Sample name: cu-0009_MG
#   SRA: SRS4899574
#
# Sample Accession: SAMN11950525
#   BioSample: SAMN11950525
#   Sample name: cu-0001_MG
#   SRA: SRS4899575
#
# Sample Accession: SAMN11950524
#   BioSample: SAMN11950524
#   Sample name: ct-0005_MG
#   SRA: SRS4899573
#
# Sample Accession: SAMN11950523
#   BioSample: SAMN11950523
#   Sample name: ct-0001_MG
#   SRA: SRS4899579
#
# Sample Accession: SAMN11950522
#   BioSample: SAMN11950522
#   Sample name: cs-0029_MG
#   SRA: SRS4899580
#
# Sample Accession: SAMN11950521
#   BioSample: SAMN11950521
#   Sample name: cs-0011_MG
#   SRA: SRS4899576
#
# Sample Accession: SAMN11950520
#   BioSample: SAMN11950520
#   Sample name: cs-0001_MG
#   SRA: SRS4899578
#
# Sample Accession: SAMN11950519
#   BioSample: SAMN11950519
#   Sample name: cr-0043_MG
#   SRA: SRS4899953
#
# Sample Accession: SAMN11950518
#   BioSample: SAMN11950518
#   Sample name: cr-0001_MG
#   SRA: SRS4899954
#
# Sample Accession: SAMN11950517
#   BioSample: SAMN11950517
#   Sample name: cq-0035_MG
#   SRA: SRS4899951
#
# Sample Accession: SAMN11950516
#   BioSample: SAMN11950516
#   Sample name: cq-0001_MG
#   SRA: SRS4899952
#
# Sample Accession: SAMN11950515
#   BioSample: SAMN11950515
#   Sample name: cp-0009_MG
#   SRA: SRS4899949
#
# Sample Accession: SAMN11950514
#   BioSample: SAMN11950514
#   Sample name: cp-0001_MG
#   SRA: SRS4899950
#
# Sample Accession: SAMN11950513
#   BioSample: SAMN11950513
#   Sample name: cn-0006_MG
#   SRA: SRS4899947
#
# Sample Accession: SAMN11950512
#   BioSample: SAMN11950512
#   Sample name: cn-0002_MG
#   SRA: SRS4899948
#
# Sample Accession: SAMN11950511
#   BioSample: SAMN11950511
#   Sample name: cm-0022_MG
#   SRA: SRS4899978
#
# Sample Accession: SAMN11950510
#   BioSample: SAMN11950510
#   Sample name: cm-0001_MG
#   SRA: SRS4899946
#
# Sample Accession: SAMN11950509
#   BioSample: SAMN11950509
#   Sample name: ck-0028_MG
#   SRA: SRS4899585
#
# Sample Accession: SAMN11950508
#   BioSample: SAMN11950508
#   Sample name: ck-0001_MG
#   SRA: SRS4899586
#
# Sample Accession: SAMN11950507
#   BioSample: SAMN11950507
#   Sample name: cj-0004_MG
#   SRA: SRS4899779
#
# Sample Accession: SAMN11950506
#   BioSample: SAMN11950506
#   Sample name: cj-0001_MG
#   SRA: SRS4899778
#
# Sample Accession: SAMN11950505
#   BioSample: SAMN11950505
#   Sample name: ci-0052_MG
#   SRA: SRS4899781
#
# Sample Accession: SAMN11950504
#   BioSample: SAMN11950504
#   Sample name: ci-0001_MG
#   SRA: SRS4899780
#
# Sample Accession: SAMN11950503
#   BioSample: SAMN11950503
#   Sample name: ch-0008_MG
#   SRA: SRS4899774
#
# Sample Accession: SAMN11950502
#   BioSample: SAMN11950502
#   Sample name: ch-0001_MG
#   SRA: SRS4899775
#
# Sample Accession: SAMN11950501
#   BioSample: SAMN11950501
#   Sample name: cg-0014_MG
#   SRA: SRS4899777
#
# Sample Accession: SAMN11950500
#   BioSample: SAMN11950500
#   Sample name: cg-0001_MG
#   SRA: SRS4899776
#
# Sample Accession: SAMN11950499
#   BioSample: SAMN11950499
#   Sample name: cf-0037_MG
#   SRA: SRS4899625
#
# Sample Accession: SAMN11950498
#   BioSample: SAMN11950498
#   Sample name: cf-0001_MG
#   SRA: SRS4899626
#
# Sample Accession: SAMN11950497
#   BioSample: SAMN11950497
#   Sample name: ce-0007_MG
#   SRA: SRS4899620
#
# Sample Accession: SAMN11950496
#   BioSample: SAMN11950496
#   Sample name: ce-0001_MG
#   SRA: SRS4899618
#
# Sample Accession: SAMN11950495
#   BioSample: SAMN11950495
#   Sample name: cd-0050_MG
#   SRA: SRS4899617
#
# Sample Accession: SAMN11950494
#   BioSample: SAMN11950494
#   Sample name: cd-0001_MG
#   SRA: SRS4899616
#
# Sample Accession: SAMN11950493
#   BioSample: SAMN11950493
#   Sample name: cc-0023_MG
#   SRA: SRS4899622
#
# Sample Accession: SAMN11950492
#   BioSample: SAMN11950492
#   Sample name: cc-0002_MG
#   SRA: SRS4899623
#
# Sample Accession: SAMN11950491
#   BioSample: SAMN11950491
#   Sample name: cb-0051_MG
#   SRA: SRS4899621
#
# Sample Accession: SAMN11950490
#   BioSample: SAMN11950490
#   Sample name: cb-0001_MG
#   SRA: SRS4899619
#
# Sample Accession: SAMN11950489
#   BioSample: SAMN11950489
#   Sample name: ca-0012_MG
#   SRA: SRS4899762
#
# Sample Accession: SAMN11950488
#   BioSample: SAMN11950488
#   Sample name: ca-0001_MG
#   SRA: SRS4899763
#
# Sample Accession: SAMN11950487
#   BioSample: SAMN11950487
#   Sample name: bz-0033_MG
#   SRA: SRS4899757
#
# Sample Accession: SAMN11950486
#   BioSample: SAMN11950486
#   Sample name: bz-0001_MG
#   SRA: SRS4899759
#
# Sample Accession: SAMN11950485
#   BioSample: SAMN11950485
#   Sample name: by-0059_MG
#   SRA: SRS4899760
#
# Sample Accession: SAMN11950484
#   BioSample: SAMN11950484
#   Sample name: by-0002_MG
#   SRA: SRS4899761
#
# Sample Accession: SAMN11950483
#   BioSample: SAMN11950483
#   Sample name: bx-0057_MG
#   SRA: SRS4899755
#
# Sample Accession: SAMN11950482
#   BioSample: SAMN11950482
#   Sample name: bx-0001_MG
#   SRA: SRS4899754
#
# Sample Accession: SAMN11950481
#   BioSample: SAMN11950481
#   Sample name: bw-0033_MG
#   SRA: SRS4899756
#
# Sample Accession: SAMN11950480
#   BioSample: SAMN11950480
#   Sample name: bw-0001_MG
#   SRA: SRS4899758
#
# Sample Accession: SAMN11950479
#   BioSample: SAMN11950479
#   Sample name: bv-0024_MG
#   SRA: SRS4899639
#
# Sample Accession: SAMN11950478
#   BioSample: SAMN11950478
#   Sample name: bv-0001_MG
#   SRA: SRS4899638
#
# Sample Accession: SAMN11950477
#   BioSample: SAMN11950477
#   Sample name: bu-0080_MG
#   SRA: SRS4899642
#
# Sample Accession: SAMN11950476
#   BioSample: SAMN11950476
#   Sample name: bu-0001_MG
#   SRA: SRS4899640
#
# Sample Accession: SAMN11950475
#   BioSample: SAMN11950475
#   Sample name: bt-0039_MG
#   SRA: SRS4899643
#
# Sample Accession: SAMN11950474
#   BioSample: SAMN11950474
#   Sample name: bt-0001_MG
#   SRA: SRS4899641
#
# Sample Accession: SAMN11950473
#   BioSample: SAMN11950473
#   Sample name: bs-0008_MG
#   SRA: SRS4899644
#
# Sample Accession: SAMN11950472
#   BioSample: SAMN11950472
#   Sample name: bs-0001_MG
#   SRA: SRS4899645
#
# Sample Accession: SAMN11950471
#   BioSample: SAMN11950471
#   Sample name: br-0002_MG
#   SRA: SRS4899647
#
# Sample Accession: SAMN11950470
#   BioSample: SAMN11950470
#   Sample name: br-0001_MG
#   SRA: SRS4899646
#
# Sample Accession: SAMN11950469
#   BioSample: SAMN11950469
#   Sample name: bq-0068_MG
#   SRA: SRS4899582
#
# Sample Accession: SAMN11950468
#   BioSample: SAMN11950468
#   Sample name: bq-0002_MG
#   SRA: SRS4899581
#
# Sample Accession: SAMN11950467
#   BioSample: SAMN11950467
#   Sample name: bp-0004_MG
#   SRA: SRS4899785
#
# Sample Accession: SAMN11950466
#   BioSample: SAMN11950466
#   Sample name: bp-0002_MG
#   SRA: SRS4899784
#
# Sample Accession: SAMN11950465
#   BioSample: SAMN11950465
#   Sample name: bo-0122_MG
#   SRA: SRS4899782
#
# Sample Accession: SAMN11950464
#   BioSample: SAMN11950464
#   Sample name: bo-0001_MG
#   SRA: SRS4899783
#
# Sample Accession: SAMN11950463
#   BioSample: SAMN11950463
#   Sample name: bn-0038_MG
#   SRA: SRS4899787
#
# Sample Accession: SAMN11950462
#   BioSample: SAMN11950462
#   Sample name: bn-0002_MG
#   SRA: SRS4899789
#
# Sample Accession: SAMN11950461
#   BioSample: SAMN11950461
#   Sample name: bm-0013_MG
#   SRA: SRS4899786
#
# Sample Accession: SAMN11950460
#   BioSample: SAMN11950460
#   Sample name: bm-0002_MG
#   SRA: SRS4899788
#
# Sample Accession: SAMN11950459
#   BioSample: SAMN11950459
#   Sample name: bl-0009_MG
#   SRA: SRS4899980
#
# Sample Accession: SAMN11950458
#   BioSample: SAMN11950458
#   Sample name: bl-0003_MG
#   SRA: SRS4899945
#
# Sample Accession: SAMN11950457
#   BioSample: SAMN11950457
#   Sample name: bk-0025_MG
#   SRA: SRS4899960
#
# Sample Accession: SAMN11950456
#   BioSample: SAMN11950456
#   Sample name: bk-0002_MG
#   SRA: SRS4899959
#
# Sample Accession: SAMN11950455
#   BioSample: SAMN11950455
#   Sample name: bi-0026_MG
#   SRA: SRS4899958
#
# Sample Accession: SAMN11950454
#   BioSample: SAMN11950454
#   Sample name: bi-0001_MG
#   SRA: SRS4899957
#
# Sample Accession: SAMN11950453
#   BioSample: SAMN11950453
#   Sample name: bh-0112_MG
#   SRA: SRS4899956
#
# Sample Accession: SAMN11950452
#   BioSample: SAMN11950452
#   Sample name: bf-0108_MG
#   SRA: SRS4899955
#
# Sample Accession: SAMN11950451
#   BioSample: SAMN11950451
#   Sample name: bf-0003_MG
#   SRA: SRS4899450
#
# Sample Accession: SAMN11950450
#   BioSample: SAMN11950450
#   Sample name: be-0085_MG
#   SRA: SRS4899445
#
# Sample Accession: SAMN11950449
#   BioSample: SAMN11950449
#   Sample name: be-0001_MG
#   SRA: SRS4899548
#
# Sample Accession: SAMN11950448
#   BioSample: SAMN11950448
#   Sample name: bd-0033_MG
#   SRA: SRS4899549
#
# Sample Accession: SAMN11950447
#   BioSample: SAMN11950447
#   Sample name: ba-0002_MG
#   SRA: SRS4899540
#
# Sample Accession: SAMN11950446
#   BioSample: SAMN11950446
#   Sample name: ba-0001_MG
#   SRA: SRS4899538
#
# Sample Accession: SAMN11950445
#   BioSample: SAMN11950445
#   Sample name: az-0036_MG
#   SRA: SRS4899720
#
# Sample Accession: SAMN11950444
#   BioSample: SAMN11950444
#   Sample name: az-0001_MG
#   SRA: SRS4899790
#
# Sample Accession: SAMN11950443
#   BioSample: SAMN11950443
#   Sample name: ay-0058_MG
#   SRA: SRS4899543
#
# Sample Accession: SAMN11950442
#   BioSample: SAMN11950442
#   Sample name: ay-0001_MG
#   SRA: SRS4899542
#
# Sample Accession: SAMN11950441
#   BioSample: SAMN11950441
#   Sample name: ax-0090_MG
#   SRA: SRS4899544
#
# Sample Accession: SAMN11950440
#   BioSample: SAMN11950440
#   Sample name: ax-0001_MG
#   SRA: SRS4899545
#
# Sample Accession: SAMN11950439
#   BioSample: SAMN11950439
#   Sample name: aw-0036_MG
#   SRA: SRS4899694
#
# Sample Accession: SAMN11950438
#   BioSample: SAMN11950438
#   Sample name: aw-0001_MG
#   SRA: SRS4899695
#
# Sample Accession: SAMN11950437
#   BioSample: SAMN11950437
#   Sample name: av-0107_MG
#   SRA: SRS4899615
#
# Sample Accession: SAMN11950436
#   BioSample: SAMN11950436
#   Sample name: av-0006_MG
#   SRA: SRS4899613
#
# Sample Accession: SAMN11950435
#   BioSample: SAMN11950435
#   Sample name: au-0066_MG
#   SRA: SRS4899691
#
# Sample Accession: SAMN11950434
#   BioSample: SAMN11950434
#   Sample name: au-0002_MG
#   SRA: SRS4899690
#
# Sample Accession: SAMN11950433
#   BioSample: SAMN11950433
#   Sample name: at-0044_MG
#   SRA: SRS4899603
#
# Sample Accession: SAMN11950432
#   BioSample: SAMN11950432
#   Sample name: at-0004_MG
#   SRA: SRS4899601
#
# Sample Accession: SAMN11950431
#   BioSample: SAMN11950431
#   Sample name: as-0033_MG
#   SRA: SRS4899610
#
# Sample Accession: SAMN11950430
#   BioSample: SAMN11950430
#   Sample name: as-0002_MG
#   SRA: SRS4899842
#
# Sample Accession: SAMN11950429
#   BioSample: SAMN11950429
#   Sample name: ar-0039_MG
#   SRA: SRS4899868
#
# Sample Accession: SAMN11950428
#   BioSample: SAMN11950428
#   Sample name: ar-0002_MG
#   SRA: SRS4899869
#
# Sample Accession: SAMN11950427
#   BioSample: SAMN11950427
#   Sample name: aq-0015_MG
#   SRA: SRS4899865
#
# Sample Accession: SAMN11950426
#   BioSample: SAMN11950426
#   Sample name: aq-0004_MG
#   SRA: SRS4899867
#
# Sample Accession: SAMN11950425
#   BioSample: SAMN11950425
#   Sample name: ap-0037_MG
#   SRA: SRS4899864
#
# Sample Accession: SAMN11950424
#   BioSample: SAMN11950424
#   Sample name: ap-0001_MG
#   SRA: SRS4899866
#
# Sample Accession: SAMN11950423
#   BioSample: SAMN11950423
#   Sample name: ao-0090_MG
#   SRA: SRS4899863
#
# Sample Accession: SAMN11950422
#   BioSample: SAMN11950422
#   Sample name: ao-0089_MG
#   SRA: SRS4899862
#
# Sample Accession: SAMN11950421
#   BioSample: SAMN11950421
#   Sample name: ao-0088_MG
#   SRA: SRS4899860
#
# Sample Accession: SAMN11950420
#   BioSample: SAMN11950420
#   Sample name: ao-0087_MG
#   SRA: SRS4899859
#
# Sample Accession: SAMN11950419
#   BioSample: SAMN11950419
#   Sample name: ao-0086_MG
#   SRA: SRS4899513
#
# Sample Accession: SAMN11950418
#   BioSample: SAMN11950418
#   Sample name: ao-0085_MG
#   SRA: SRS4899512
#
# Sample Accession: SAMN11950417
#   BioSample: SAMN11950417
#   Sample name: ao-0084_MG
#   SRA: SRS4899517
#
# Sample Accession: SAMN11950416
#   BioSample: SAMN11950416
#   Sample name: ao-0083_MG
#   SRA: SRS4899482
#
# Sample Accession: SAMN11950415
#   BioSample: SAMN11950415
#   Sample name: ao-0082_MG
#   SRA: SRS4899516
#
# Sample Accession: SAMN11950414
#   BioSample: SAMN11950414
#   Sample name: ao-0081_MG
#   SRA: SRS4899514
#
# Sample Accession: SAMN11950413
#   BioSample: SAMN11950413
#   Sample name: ao-0080_MG
#   SRA: SRS4899522
#
# Sample Accession: SAMN11950412
#   BioSample: SAMN11950412
#   Sample name: ao-0079_MG
#   SRA: SRS4899520
#
# Sample Accession: SAMN11950411
#   BioSample: SAMN11950411
#   Sample name: ao-0078_MG
#   SRA: SRS4899518
#
# Sample Accession: SAMN11950410
#   BioSample: SAMN11950410
#   Sample name: ao-0077_MG
#   SRA: SRS4899519
#
# Sample Accession: SAMN11950409
#   BioSample: SAMN11950409
#   Sample name: ao-0076_MG
#   SRA: SRS4899651
#
# Sample Accession: SAMN11950408
#   BioSample: SAMN11950408
#   Sample name: ao-0075_MG
#   SRA: SRS4899652
#
# Sample Accession: SAMN11950407
#   BioSample: SAMN11950407
#   Sample name: ao-0074_MG
#   SRA: SRS4899657
#
# Sample Accession: SAMN11950406
#   BioSample: SAMN11950406
#   Sample name: ao-0073_MG
#   SRA: SRS4899659
#
# Sample Accession: SAMN11950405
#   BioSample: SAMN11950405
#   Sample name: ao-0072_MG
#   SRA: SRS4899660
#
# Sample Accession: SAMN11950404
#   BioSample: SAMN11950404
#   Sample name: ao-0071_MG
#   SRA: SRS4899661
#
# Sample Accession: SAMN11950403
#   BioSample: SAMN11950403
#   Sample name: ao-0070_MG
#   SRA: SRS4899654
#
# Sample Accession: SAMN11950402
#   BioSample: SAMN11950402
#   Sample name: ao-0069_MG
#   SRA: SRS4899846
#
# Sample Accession: SAMN11950401
#   BioSample: SAMN11950401
#   Sample name: ao-0068_MG
#   SRA: SRS4899656
#
# Sample Accession: SAMN11950400
#   BioSample: SAMN11950400
#   Sample name: ao-0066_MG
#   SRA: SRS4899658
#
# Sample Accession: SAMN11950399
#   BioSample: SAMN11950399
#   Sample name: ao-0065_MG
#   SRA: SRS4899602
#
# Sample Accession: SAMN11950398
#   BioSample: SAMN11950398
#   Sample name: ao-0064_MG
#   SRA: SRS4899600
#
# Sample Accession: SAMN11950397
#   BioSample: SAMN11950397
#   Sample name: ao-0063_MG
#   SRA: SRS4899608
#
# Sample Accession: SAMN11950396
#   BioSample: SAMN11950396
#   Sample name: ao-0062_MG
#   SRA: SRS4899609
#
# Sample Accession: SAMN11950395
#   BioSample: SAMN11950395
#   Sample name: ao-0061_MG
#   SRA: SRS4899611
#
# Sample Accession: SAMN11950394
#   BioSample: SAMN11950394
#   Sample name: ao-0060_MG
#   SRA: SRS4899612
#
# Sample Accession: SAMN11950393
#   BioSample: SAMN11950393
#   Sample name: ao-0059_MG
#   SRA: SRS4899604
#
# Sample Accession: SAMN11950392
#   BioSample: SAMN11950392
#   Sample name: ao-0058_MG
#   SRA: SRS4899605
#
# Sample Accession: SAMN11950391
#   BioSample: SAMN11950391
#   Sample name: ao-0057_MG
#   SRA: SRS4899606
#
# Sample Accession: SAMN11950390
#   BioSample: SAMN11950390
#   Sample name: ao-0050_MG
#   SRA: SRS4899607
#
# Sample Accession: SAMN11950389
#   BioSample: SAMN11950389
#   Sample name: ao-0049_MG
#   SRA: SRS4899472
#
# Sample Accession: SAMN11950388
#   BioSample: SAMN11950388
#   Sample name: ao-0048_MG
#   SRA: SRS4899470
#
# Sample Accession: SAMN11950387
#   BioSample: SAMN11950387
#   Sample name: ao-0047_MG
#   SRA: SRS4899474
#
# Sample Accession: SAMN11950386
#   BioSample: SAMN11950386
#   Sample name: ao-0046_MG
#   SRA: SRS4899475
#
# Sample Accession: SAMN11950385
#   BioSample: SAMN11950385
#   Sample name: ao-0045_MG
#   SRA: SRS4899473
#
# Sample Accession: SAMN11950384
#   BioSample: SAMN11950384
#   Sample name: ao-0044_MG
#   SRA: SRS4899471
#
# Sample Accession: SAMN11950383
#   BioSample: SAMN11950383
#   Sample name: ao-0043_MG
#   SRA: SRS4899479
#
# Sample Accession: SAMN11950382
#   BioSample: SAMN11950382
#   Sample name: ao-0042_MG
#   SRA: SRS4899477
#
# Sample Accession: SAMN11950381
#   BioSample: SAMN11950381
#   Sample name: ao-0041_MG
#   SRA: SRS4899478
#
# Sample Accession: SAMN11950380
#   BioSample: SAMN11950380
#   Sample name: ao-0040_MG
#   SRA: SRS4899476
#
# Sample Accession: SAMN11950379
#   BioSample: SAMN11950379
#   Sample name: ao-0039_MG
#   SRA: SRS4899458
#
# Sample Accession: SAMN11950378
#   BioSample: SAMN11950378
#   Sample name: ao-0038_MG
#   SRA: SRS4899932
#
# Sample Accession: SAMN11950377
#   BioSample: SAMN11950377
#   Sample name: ao-0037_MG
#   SRA: SRS4899925
#
# Sample Accession: SAMN11950376
#   BioSample: SAMN11950376
#   Sample name: ao-0036_MG
#   SRA: SRS4899870
#
# Sample Accession: SAMN11950375
#   BioSample: SAMN11950375
#   Sample name: ao-0035_MG
#   SRA: SRS4899636
#
# Sample Accession: SAMN11950374
#   BioSample: SAMN11950374
#   Sample name: ao-0034_MG
#   SRA: SRS4899598
#
# Sample Accession: SAMN11950373
#   BioSample: SAMN11950373
#   Sample name: ao-0033_MG
#   SRA: SRS4899927
#
# Sample Accession: SAMN11950372
#   BioSample: SAMN11950372
#   Sample name: ao-0032_MG
#   SRA: SRS4899930
#
# Sample Accession: SAMN11950371
#   BioSample: SAMN11950371
#   Sample name: ao-0031_MG
#   SRA: SRS4899928
#
# Sample Accession: SAMN11950370
#   BioSample: SAMN11950370
#   Sample name: ao-0030_MG
#   SRA: SRS4899929
#
# Sample Accession: SAMN11950369
#   BioSample: SAMN11950369
#   Sample name: ao-0029_MG
#   SRA: SRS4899753
#
# Sample Accession: SAMN11950368
#   BioSample: SAMN11950368
#   Sample name: ao-0028_MG
#   SRA: SRS4899751
#
# Sample Accession: SAMN11950367
#   BioSample: SAMN11950367
#   Sample name: ao-0027_MG
#   SRA: SRS4899745
#
# Sample Accession: SAMN11950366
#   BioSample: SAMN11950366
#   Sample name: ao-0026_MG
#   SRA: SRS4899743
#
# Sample Accession: SAMN11950365
#   BioSample: SAMN11950365
#   Sample name: ao-0025_MG
#   SRA: SRS4899747
#
# Sample Accession: SAMN11950364
#   BioSample: SAMN11950364
#   Sample name: ao-0017_MG
#   SRA: SRS4899746
#
# Sample Accession: SAMN11950363
#   BioSample: SAMN11950363
#   Sample name: ao-0016_MG
#   SRA: SRS4899748
#
# Sample Accession: SAMN11950362
#   BioSample: SAMN11950362
#   Sample name: ao-0015_MG
#   SRA: SRS4899749
#
# Sample Accession: SAMN11950361
#   BioSample: SAMN11950361
#   Sample name: ao-0014_MG
#   SRA: SRS4899752
#
# Sample Accession: SAMN11950360
#   BioSample: SAMN11950360
#   Sample name: ao-0013_MG
#   SRA: SRS4899750
#
# Sample Accession: SAMN11950359
#   BioSample: SAMN11950359
#   Sample name: ao-0012_MG
#   SRA: SRS4899696
#
# Sample Accession: SAMN11950358
#   BioSample: SAMN11950358
#   Sample name: ao-0011_MG
#   SRA: SRS4899697
#
# Sample Accession: SAMN11950357
#   BioSample: SAMN11950357
#   Sample name: ao-0010_MG
#   SRA: SRS4899698
#
# Sample Accession: SAMN11950356
#   BioSample: SAMN11950356
#   Sample name: ao-0009_MG
#   SRA: SRS4899699
#
# Sample Accession: SAMN11950355
#   BioSample: SAMN11950355
#   Sample name: ao-0008_MG
#   SRA: SRS4899701
#
# Sample Accession: SAMN11950354
#   BioSample: SAMN11950354
#   Sample name: ao-0007_MG
#   SRA: SRS4899700
#
# Sample Accession: SAMN11950353
#   BioSample: SAMN11950353
#   Sample name: ao-0006_MG
#   SRA: SRS4899702
#
# Sample Accession: SAMN11950352
#   BioSample: SAMN11950352
#   Sample name: ao-0004_MG
#   SRA: SRS4899704
#
# Sample Accession: SAMN11950351
#   BioSample: SAMN11950351
#   Sample name: ao-0003_MG
#   SRA: SRS4899703
#
# Sample Accession: SAMN11950350
#   BioSample: SAMN11950350
#   Sample name: ao-0001_MG
#   SRA: SRS4899705
#
# Sample Accession: SAMN11950349
#   BioSample: SAMN11950349
#   Sample name: an-0083_MG
#   SRA: SRS4899536
#
# Sample Accession: SAMN11950348
#   BioSample: SAMN11950348
#   Sample name: an-0082_MG
#   SRA: SRS4899537
#
# Sample Accession: SAMN11950347
#   BioSample: SAMN11950347
#   Sample name: an-0081_MG
#   SRA: SRS4899535
#
# Sample Accession: SAMN11950346
#   BioSample: SAMN11950346
#   Sample name: an-0080_MG
#   SRA: SRS4899534
#
# Sample Accession: SAMN11950345
#   BioSample: SAMN11950345
#   Sample name: an-0077_MG
#   SRA: SRS4899533
#
# Sample Accession: SAMN11950344
#   BioSample: SAMN11950344
#   Sample name: an-0076_MG
#   SRA: SRS4899532
#
# Sample Accession: SAMN11950343
#   BioSample: SAMN11950343
#   Sample name: an-0075_MG
#   SRA: SRS4899531
#
# Sample Accession: SAMN11950342
#   BioSample: SAMN11950342
#   Sample name: an-0074_MG
#   SRA: SRS4899530
#
# Sample Accession: SAMN11950341
#   BioSample: SAMN11950341
#   Sample name: an-0073_MG
#   SRA: SRS4899528
#
# Sample Accession: SAMN11950340
#   BioSample: SAMN11950340
#   Sample name: an-0072_MG
#   SRA: SRS4899529
#
# Sample Accession: SAMN11950339
#   BioSample: SAMN11950339
#   Sample name: an-0071_MG
#   SRA: SRS4899487
#
# Sample Accession: SAMN11950338
#   BioSample: SAMN11950338
#   Sample name: an-0070_MG
#   SRA: SRS4899488
#
# Sample Accession: SAMN11950337
#   BioSample: SAMN11950337
#   Sample name: an-0069_MG
#   SRA: SRS4899496
#
# Sample Accession: SAMN11950336
#   BioSample: SAMN11950336
#   Sample name: an-0067_MG
#   SRA: SRS4899497
#
# Sample Accession: SAMN11950335
#   BioSample: SAMN11950335
#   Sample name: an-0066_MG
#   SRA: SRS4899494
#
# Sample Accession: SAMN11950334
#   BioSample: SAMN11950334
#   Sample name: an-0065_MG
#   SRA: SRS4899495
#
# Sample Accession: SAMN11950333
#   BioSample: SAMN11950333
#   Sample name: an-0064_MG
#   SRA: SRS4899493
#
# Sample Accession: SAMN11950332
#   BioSample: SAMN11950332
#   Sample name: an-0063_MG
#   SRA: SRS4899492
#
# Sample Accession: SAMN11950331
#   BioSample: SAMN11950331
#   Sample name: an-0062_MG
#   SRA: SRS4899491
#
# Sample Accession: SAMN11950330
#   BioSample: SAMN11950330
#   Sample name: an-0061_MG
#   SRA: SRS4899490
#
# Sample Accession: SAMN11950329
#   BioSample: SAMN11950329
#   Sample name: an-0060_MG
#   SRA: SRS4899877
#
# Sample Accession: SAMN11950328
#   BioSample: SAMN11950328
#   Sample name: an-0058_MG
#   SRA: SRS4899876
#
# Sample Accession: SAMN11950327
#   BioSample: SAMN11950327
#   Sample name: an-0056_MG
#   SRA: SRS4899883
#
# Sample Accession: SAMN11950326
#   BioSample: SAMN11950326
#   Sample name: an-0055_MG
#   SRA: SRS4899882
#
# Sample Accession: SAMN11950325
#   BioSample: SAMN11950325
#   Sample name: an-0054_MG
#   SRA: SRS4899886
#
# Sample Accession: SAMN11950324
#   BioSample: SAMN11950324
#   Sample name: an-0053_MG
#   SRA: SRS4899884
#
# Sample Accession: SAMN11950323
#   BioSample: SAMN11950323
#   Sample name: an-0052_MG
#   SRA: SRS4899880
#
# Sample Accession: SAMN11950322
#   BioSample: SAMN11950322
#   Sample name: an-0051_MG
#   SRA: SRS4899878
#
# Sample Accession: SAMN11950321
#   BioSample: SAMN11950321
#   Sample name: an-0050_MG
#   SRA: SRS4899881
#
# Sample Accession: SAMN11950320
#   BioSample: SAMN11950320
#   Sample name: an-0049_MG
#   SRA: SRS4899879
#
# Sample Accession: SAMN11950319
#   BioSample: SAMN11950319
#   Sample name: an-0048_MG
#   SRA: SRS4899771
#
# Sample Accession: SAMN11950318
#   BioSample: SAMN11950318
#   Sample name: an-0047_MG
#   SRA: SRS4899773
#
# Sample Accession: SAMN11950317
#   BioSample: SAMN11950317
#   Sample name: an-0046_MG
#   SRA: SRS4899769
#
# Sample Accession: SAMN11950316
#   BioSample: SAMN11950316
#   Sample name: an-0045_MG
#   SRA: SRS4899768
#
# Sample Accession: SAMN11950315
#   BioSample: SAMN11950315
#   Sample name: an-0044_MG
#   SRA: SRS4899770
#
# Sample Accession: SAMN11950314
#   BioSample: SAMN11950314
#   Sample name: an-0043_MG
#   SRA: SRS4899772
#
# Sample Accession: SAMN11950313
#   BioSample: SAMN11950313
#   Sample name: an-0042_MG
#   SRA: SRS4899764
#
# Sample Accession: SAMN11950312
#   BioSample: SAMN11950312
#   Sample name: an-0041_MG
#   SRA: SRS4899765
#
# Sample Accession: SAMN11950311
#   BioSample: SAMN11950311
#   Sample name: an-0040_MG
#   SRA: SRS4899766
#
# Sample Accession: SAMN11950310
#   BioSample: SAMN11950310
#   Sample name: an-0039_MG
#   SRA: SRS4899767
#
# Sample Accession: SAMN11950309
#   BioSample: SAMN11950309
#   Sample name: an-0038_MG
#   SRA: SRS4899637
#
# Sample Accession: SAMN11950308
#   BioSample: SAMN11950308
#   Sample name: an-0037_MG
#   SRA: SRS4899634
#
# Sample Accession: SAMN11950307
#   BioSample: SAMN11950307
#   Sample name: an-0036_MG
#   SRA: SRS4899630
#
# Sample Accession: SAMN11950306
#   BioSample: SAMN11950306
#   Sample name: an-0035_MG
#   SRA: SRS4899629
#
# Sample Accession: SAMN11950305
#   BioSample: SAMN11950305
#   Sample name: an-0034_MG
#   SRA: SRS4899628
#
# Sample Accession: SAMN11950304
#   BioSample: SAMN11950304
#   Sample name: an-0030_MG
#   SRA: SRS4899627
#
# Sample Accession: SAMN11950303
#   BioSample: SAMN11950303
#   Sample name: an-0028_MG
#   SRA: SRS4899635
#
# Sample Accession: SAMN11950302
#   BioSample: SAMN11950302
#   Sample name: an-0027_MG
#   SRA: SRS4899633
#
# Sample Accession: SAMN11950301
#   BioSample: SAMN11950301
#   Sample name: an-0026_MG
#   SRA: SRS4899632
#
# Sample Accession: SAMN11950300
#   BioSample: SAMN11950300
#   Sample name: an-0025_MG
#   SRA: SRS4899631
#
# Sample Accession: SAMN11950299
#   BioSample: SAMN11950299
#   Sample name: an-0023_MG
#   SRA: SRS4899454
#
# Sample Accession: SAMN11950298
#   BioSample: SAMN11950298
#   Sample name: an-0019_MG
#   SRA: SRS4899452
#
# Sample Accession: SAMN11950297
#   BioSample: SAMN11950297
#   Sample name: an-0017_MG
#   SRA: SRS4899583
#
# Sample Accession: SAMN11950296
#   BioSample: SAMN11950296
#   Sample name: an-0016_MG
#   SRA: SRS4899443
#
# Sample Accession: SAMN11950295
#   BioSample: SAMN11950295
#   Sample name: an-0015_MG
#   SRA: SRS4899446
#
# Sample Accession: SAMN11950294
#   BioSample: SAMN11950294
#   Sample name: an-0013_MG
#   SRA: SRS4899444
#
# Sample Accession: SAMN11950293
#   BioSample: SAMN11950293
#   Sample name: an-0009_MG
#   SRA: SRS4899447
#
# Sample Accession: SAMN11950292
#   BioSample: SAMN11950292
#   Sample name: an-0006_MG
#   SRA: SRS4899448
#
# Sample Accession: SAMN11950291
#   BioSample: SAMN11950291
#   Sample name: an-0005_MG
#   SRA: SRS4899584
#
# Sample Accession: SAMN11950290
#   BioSample: SAMN11950290
#   Sample name: an-0004_MG
#   SRA: SRS4899449
#
# Sample Accession: SAMN11950289
#   BioSample: SAMN11950289
#   Sample name: an-0003_MG
#   SRA: SRS4899456
#
# Sample Accession: SAMN11950288
#   BioSample: SAMN11950288
#   Sample name: an-0002_MG
#   SRA: SRS4899457
#
# Sample Accession: SAMN11950287
#   BioSample: SAMN11950287
#   Sample name: an-0001_MG
#   SRA: SRS4899567
#
# Sample Accession: SAMN11950286
#   BioSample: SAMN11950286
#   Sample name: am-0231_MG
#   SRA: SRS4899568
#
# Sample Accession: SAMN11950285
#   BioSample: SAMN11950285
#   Sample name: am-0230_MG
#   SRA: SRS4899564
#
# Sample Accession: SAMN11950284
#   BioSample: SAMN11950284
#   Sample name: am-0229_MG
#   SRA: SRS4899565
#
# Sample Accession: SAMN11950283
#   BioSample: SAMN11950283
#   Sample name: am-0228_MG
#   SRA: SRS4899572
#
# Sample Accession: SAMN11950282
#   BioSample: SAMN11950282
#   Sample name: am-0227_MG
#   SRA: SRS4899571
#
# Sample Accession: SAMN11950281
#   BioSample: SAMN11950281
#   Sample name: am-0226_MG
#   SRA: SRS4899451
#
# Sample Accession: SAMN11950280
#   BioSample: SAMN11950280
#   Sample name: am-0225_MG
#   SRA: SRS4899509
#
# Sample Accession: SAMN11950279
#   BioSample: SAMN11950279
#   Sample name: am-0224_MG
#   SRA: SRS4899663
#
# Sample Accession: SAMN11950278
#   BioSample: SAMN11950278
#   Sample name: am-0223_MG
#   SRA: SRS4899662
#
# Sample Accession: SAMN11950277
#   BioSample: SAMN11950277
#   Sample name: am-0222_MG
#   SRA: SRS4899666
#
# Sample Accession: SAMN11950276
#   BioSample: SAMN11950276
#   Sample name: am-0221_MG
#   SRA: SRS4899667
#
# Sample Accession: SAMN11950275
#   BioSample: SAMN11950275
#   Sample name: am-0220_MG
#   SRA: SRS4899665
#
# Sample Accession: SAMN11950274
#   BioSample: SAMN11950274
#   Sample name: am-0219_MG
#   SRA: SRS4899664
#
# Sample Accession: SAMN11950273
#   BioSample: SAMN11950273
#   Sample name: am-0218_MG
#   SRA: SRS4899671
#
# Sample Accession: SAMN11950272
#   BioSample: SAMN11950272
#   Sample name: am-0217_MG
#   SRA: SRS4899669
#
# Sample Accession: SAMN11950271
#   BioSample: SAMN11950271
#   Sample name: am-0216_MG
#   SRA: SRS4899670
#
# Sample Accession: SAMN11950270
#   BioSample: SAMN11950270
#   Sample name: am-0215_MG
#   SRA: SRS4899668
#
# Sample Accession: SAMN11950269
#   BioSample: SAMN11950269
#   Sample name: am-0214_MG
#   SRA: SRS4899831
#
# Sample Accession: SAMN11950268
#   BioSample: SAMN11950268
#   Sample name: am-0213_MG
#   SRA: SRS4899833
#
# Sample Accession: SAMN11950267
#   BioSample: SAMN11950267
#   Sample name: am-0212_MG
#   SRA: SRS4899837
#
# Sample Accession: SAMN11950266
#   BioSample: SAMN11950266
#   Sample name: am-0211_MG
#   SRA: SRS4899839
#
# Sample Accession: SAMN11950265
#   BioSample: SAMN11950265
#   Sample name: am-0210_MG
#   SRA: SRS4899838
#
# Sample Accession: SAMN11950264
#   BioSample: SAMN11950264
#   Sample name: am-0209_MG
#   SRA: SRS4899840
#
# Sample Accession: SAMN11950263
#   BioSample: SAMN11950263
#   Sample name: am-0208_MG
#   SRA: SRS4899832
#
# Sample Accession: SAMN11950262
#   BioSample: SAMN11950262
#   Sample name: am-0207_MG
#   SRA: SRS4899834
#
# Sample Accession: SAMN11950261
#   BioSample: SAMN11950261
#   Sample name: am-0206_MG
#   SRA: SRS4899836
#
# Sample Accession: SAMN11950260
#   BioSample: SAMN11950260
#   Sample name: am-0205_MG
#   SRA: SRS4899835
#
# Sample Accession: SAMN11950259
#   BioSample: SAMN11950259
#   Sample name: am-0204_MG
#   SRA: SRS4899898
#
# Sample Accession: SAMN11950258
#   BioSample: SAMN11950258
#   Sample name: am-0203_MG
#   SRA: SRS4899552
#
# Sample Accession: SAMN11950257
#   BioSample: SAMN11950257
#   Sample name: am-0202_MG
#   SRA: SRS4899550
#
# Sample Accession: SAMN11950256
#   BioSample: SAMN11950256
#   Sample name: am-0201_MG
#   SRA: SRS4899551
#
# Sample Accession: SAMN11950255
#   BioSample: SAMN11950255
#   Sample name: am-0200_MG
#   SRA: SRS4899893
#
# Sample Accession: SAMN11950254
#   BioSample: SAMN11950254
#   Sample name: am-0199_MG
#   SRA: SRS4899892
#
# Sample Accession: SAMN11950253
#   BioSample: SAMN11950253
#   Sample name: am-0198_MG
#   SRA: SRS4899887
#
# Sample Accession: SAMN11950252
#   BioSample: SAMN11950252
#   Sample name: am-0197_MG
#   SRA: SRS4899885
#
# Sample Accession: SAMN11950251
#   BioSample: SAMN11950251
#   Sample name: am-0196_MG
#   SRA: SRS4899888
#
# Sample Accession: SAMN11950250
#   BioSample: SAMN11950250
#   Sample name: am-0195_MG
#   SRA: SRS4899889
#
# Sample Accession: SAMN11950249
#   BioSample: SAMN11950249
#   Sample name: am-0194_MG
#   SRA: SRS4899506
#
# Sample Accession: SAMN11950248
#   BioSample: SAMN11950248
#   Sample name: am-0192_MG
#   SRA: SRS4899943
#
# Sample Accession: SAMN11950247
#   BioSample: SAMN11950247
#   Sample name: am-0190_MG
#   SRA: SRS4899504
#
# Sample Accession: SAMN11950246
#   BioSample: SAMN11950246
#   Sample name: am-0189_MG
#   SRA: SRS4899505
#
# Sample Accession: SAMN11950245
#   BioSample: SAMN11950245
#   Sample name: am-0188_MG
#   SRA: SRS4899502
#
# Sample Accession: SAMN11950244
#   BioSample: SAMN11950244
#   Sample name: am-0187_MG
#   SRA: SRS4899503
#
# Sample Accession: SAMN11950243
#   BioSample: SAMN11950243
#   Sample name: am-0186_MG
#   SRA: SRS4899500
#
# Sample Accession: SAMN11950242
#   BioSample: SAMN11950242
#   Sample name: am-0185_MG
#   SRA: SRS4899501
#
# Sample Accession: SAMN11950241
#   BioSample: SAMN11950241
#   Sample name: am-0184_MG
#   SRA: SRS4899499
#
# Sample Accession: SAMN11950240
#   BioSample: SAMN11950240
#   Sample name: am-0183_MG
#   SRA: SRS4899498
#
# Sample Accession: SAMN11950239
#   BioSample: SAMN11950239
#   Sample name: am-0182_MG
#   SRA: SRS4899554
#
# Sample Accession: SAMN11950238
#   BioSample: SAMN11950238
#   Sample name: am-0181_MG
#   SRA: SRS4899553
#
# Sample Accession: SAMN11950237
#   BioSample: SAMN11950237
#   Sample name: am-0180_MG
#   SRA: SRS4899563
#
# Sample Accession: SAMN11950236
#   BioSample: SAMN11950236
#   Sample name: am-0179_MG
#   SRA: SRS4899561
#
# Sample Accession: SAMN11950235
#   BioSample: SAMN11950235
#   Sample name: am-0178_MG
#   SRA: SRS4899562
#
# Sample Accession: SAMN11950234
#   BioSample: SAMN11950234
#   Sample name: am-0177_MG
#   SRA: SRS4899560
#
# Sample Accession: SAMN11950233
#   BioSample: SAMN11950233
#   Sample name: am-0176_MG
#   SRA: SRS4899558
#
# Sample Accession: SAMN11950232
#   BioSample: SAMN11950232
#   Sample name: am-0175_MG
#   SRA: SRS4899559
#
# Sample Accession: SAMN11950231
#   BioSample: SAMN11950231
#   Sample name: am-0174_MG
#   SRA: SRS4899557
#
# Sample Accession: SAMN11950230
#   BioSample: SAMN11950230
#   Sample name: am-0173_MG
#   SRA: SRS4899556
#
# Sample Accession: SAMN11950229
#   BioSample: SAMN11950229
#   Sample name: am-0172_MG
#   SRA: SRS4899717
#
# Sample Accession: SAMN11950228
#   BioSample: SAMN11950228
#   Sample name: am-0171_MG
#   SRA: SRS4899718
#
# Sample Accession: SAMN11950227
#   BioSample: SAMN11950227
#   Sample name: am-0169_MG
#   SRA: SRS4899433
#
# Sample Accession: SAMN11950226
#   BioSample: SAMN11950226
#   Sample name: am-0168_MG
#   SRA: SRS4899432
#
# Sample Accession: SAMN11950225
#   BioSample: SAMN11950225
#   Sample name: am-0167_MG
#   SRA: SRS4899431
#
# Sample Accession: SAMN11950224
#   BioSample: SAMN11950224
#   Sample name: am-0166_MG
#   SRA: SRS4899434
#
# Sample Accession: SAMN11950223
#   BioSample: SAMN11950223
#   Sample name: am-0165_MG
#   SRA: SRS4899707
#
# Sample Accession: SAMN11950222
#   BioSample: SAMN11950222
#   Sample name: am-0164_MG
#   SRA: SRS4899706
#
# Sample Accession: SAMN11950221
#   BioSample: SAMN11950221
#   Sample name: am-0163_MG
#   SRA: SRS4899708
#
# Sample Accession: SAMN11950220
#   BioSample: SAMN11950220
#   Sample name: am-0162_MG
#   SRA: SRS4899709
#
# Sample Accession: SAMN11950219
#   BioSample: SAMN11950219
#   Sample name: am-0161_MG
#   SRA: SRS4899812
#
# Sample Accession: SAMN11950218
#   BioSample: SAMN11950218
#   Sample name: am-0160_MG
#   SRA: SRS4899810
#
# Sample Accession: SAMN11950217
#   BioSample: SAMN11950217
#   Sample name: am-0159_MG
#   SRA: SRS4899813
#
# Sample Accession: SAMN11950216
#   BioSample: SAMN11950216
#   Sample name: am-0158_MG
#   SRA: SRS4899814
#
# Sample Accession: SAMN11950215
#   BioSample: SAMN11950215
#   Sample name: am-0157_MG
#   SRA: SRS4899817
#
# Sample Accession: SAMN11950214
#   BioSample: SAMN11950214
#   Sample name: am-0156_MG
#   SRA: SRS4899815
#
# Sample Accession: SAMN11950213
#   BioSample: SAMN11950213
#   Sample name: am-0155_MG
#   SRA: SRS4899818
#
# Sample Accession: SAMN11950212
#   BioSample: SAMN11950212
#   Sample name: am-0153_MG
#   SRA: SRS4899816
#
# Sample Accession: SAMN11950211
#   BioSample: SAMN11950211
#   Sample name: am-0152_MG
#   SRA: SRS4899821
#
# Sample Accession: SAMN11950210
#   BioSample: SAMN11950210
#   Sample name: am-0151_MG
#   SRA: SRS4899819
#
# Sample Accession: SAMN11950209
#   BioSample: SAMN11950209
#   Sample name: am-0150_MG
#   SRA: SRS4899977
#
# Sample Accession: SAMN11950208
#   BioSample: SAMN11950208
#   Sample name: am-0149_MG
#   SRA: SRS4899979
#
# Sample Accession: SAMN11950207
#   BioSample: SAMN11950207
#   Sample name: am-0148_MG
#   SRA: SRS4899982
#
# Sample Accession: SAMN11950206
#   BioSample: SAMN11950206
#   Sample name: am-0147_MG
#   SRA: SRS4899985
#
# Sample Accession: SAMN11950205
#   BioSample: SAMN11950205
#   Sample name: am-0146_MG
#   SRA: SRS4899981
#
# Sample Accession: SAMN11950204
#   BioSample: SAMN11950204
#   Sample name: am-0143_MG
#   SRA: SRS4899983
#
# Sample Accession: SAMN11950203
#   BioSample: SAMN11950203
#   Sample name: am-0142_MG
#   SRA: SRS4899987
#
# Sample Accession: SAMN11950202
#   BioSample: SAMN11950202
#   Sample name: am-0141_MG
#   SRA: SRS4899989
#
# Sample Accession: SAMN11950201
#   BioSample: SAMN11950201
#   Sample name: am-0140_MG
#   SRA: SRS4899984
#
# Sample Accession: SAMN11950200
#   BioSample: SAMN11950200
#   Sample name: am-0139_MG
#   SRA: SRS4899986
#
# Sample Accession: SAMN11950199
#   BioSample: SAMN11950199
#   Sample name: am-0138_MG
#   SRA: SRS4899990
#
# Sample Accession: SAMN11950198
#   BioSample: SAMN11950198
#   Sample name: am-0137_MG
#   SRA: SRS4899991
#
# Sample Accession: SAMN11950197
#   BioSample: SAMN11950197
#   Sample name: am-0136_MG
#   SRA: SRS4899435
#
# Sample Accession: SAMN11950196
#   BioSample: SAMN11950196
#   Sample name: am-0135_MG
#   SRA: SRS4899436
#
# Sample Accession: SAMN11950195
#   BioSample: SAMN11950195
#   Sample name: am-0134_MG
#   SRA: SRS4899992
#
# Sample Accession: SAMN11950194
#   BioSample: SAMN11950194
#   Sample name: am-0132_MG
#   SRA: SRS4899993
#
# Sample Accession: SAMN11950193
#   BioSample: SAMN11950193
#   Sample name: am-0131_MG
#   SRA: SRS4899439
#
# Sample Accession: SAMN11950192
#   BioSample: SAMN11950192
#   Sample name: am-0130_MG
#   SRA: SRS4899440
#
# Sample Accession: SAMN11950191
#   BioSample: SAMN11950191
#   Sample name: am-0129_MG
#   SRA: SRS4899437
#
# Sample Accession: SAMN11950190
#   BioSample: SAMN11950190
#   Sample name: am-0128_MG
#   SRA: SRS4899438
#
# Sample Accession: SAMN11950189
#   BioSample: SAMN11950189
#   Sample name: am-0127_MG
#   SRA: SRS4899822
#
# Sample Accession: SAMN11950188
#   BioSample: SAMN11950188
#   Sample name: am-0126_MG
#   SRA: SRS4899820
#
# Sample Accession: SAMN11950187
#   BioSample: SAMN11950187
#   Sample name: am-0125_MG
#   SRA: SRS4899824
#
# Sample Accession: SAMN11950186
#   BioSample: SAMN11950186
#   Sample name: am-0124_MG
#   SRA: SRS4899823
#
# Sample Accession: SAMN11950185
#   BioSample: SAMN11950185
#   Sample name: am-0123_MG
#   SRA: SRS4899826
#
# Sample Accession: SAMN11950184
#   BioSample: SAMN11950184
#   Sample name: am-0122_MG
#   SRA: SRS4899825
#
# Sample Accession: SAMN11950183
#   BioSample: SAMN11950183
#   Sample name: am-0121_MG
#   SRA: SRS4899828
#
# Sample Accession: SAMN11950182
#   BioSample: SAMN11950182
#   Sample name: am-0120_MG
#   SRA: SRS4899827
#
# Sample Accession: SAMN11950181
#   BioSample: SAMN11950181
#   Sample name: am-0119_MG
#   SRA: SRS4899829
#
# Sample Accession: SAMN11950180
#   BioSample: SAMN11950180
#   Sample name: am-0118_MG
#   SRA: SRS4899830
#
# Sample Accession: SAMN11950179
#   BioSample: SAMN11950179
#   Sample name: am-0117_MG
#   SRA: SRS4899524
#
# Sample Accession: SAMN11950178
#   BioSample: SAMN11950178
#   Sample name: am-0116_MG
#   SRA: SRS4899972
#
# Sample Accession: SAMN11950177
#   BioSample: SAMN11950177
#   Sample name: am-0115_MG
#   SRA: SRS4899965
#
# Sample Accession: SAMN11950176
#   BioSample: SAMN11950176
#   Sample name: am-0114_MG
#   SRA: SRS4899969
#
# Sample Accession: SAMN11950175
#   BioSample: SAMN11950175
#   Sample name: am-0113_MG
#   SRA: SRS4899521
#
# Sample Accession: SAMN11950174
#   BioSample: SAMN11950174
#   Sample name: am-0112_MG
#   SRA: SRS4899523
#
# Sample Accession: SAMN11950173
#   BioSample: SAMN11950173
#   Sample name: am-0111_MG
#   SRA: SRS4899961
#
# Sample Accession: SAMN11950172
#   BioSample: SAMN11950172
#   Sample name: am-0110_MG
#   SRA: SRS4899962
#
# Sample Accession: SAMN11950171
#   BioSample: SAMN11950171
#   Sample name: am-0109_MG
#   SRA: SRS4899963
#
# Sample Accession: SAMN11950170
#   BioSample: SAMN11950170
#   Sample name: am-0108_MG
#   SRA: SRS4899964
#
# Sample Accession: SAMN11950169
#   BioSample: SAMN11950169
#   Sample name: am-0107_MG
#   SRA: SRS4899672
#
# Sample Accession: SAMN11950168
#   BioSample: SAMN11950168
#   Sample name: am-0106_MG
#   SRA: SRS4899673
#
# Sample Accession: SAMN11950167
#   BioSample: SAMN11950167
#   Sample name: am-0105_MG
#   SRA: SRS4899798
#
# Sample Accession: SAMN11950166
#   BioSample: SAMN11950166
#   Sample name: am-0104_MG
#   SRA: SRS4899797
#
# Sample Accession: SAMN11950165
#   BioSample: SAMN11950165
#   Sample name: am-0103_MG
#   SRA: SRS4899796
#
# Sample Accession: SAMN11950164
#   BioSample: SAMN11950164
#   Sample name: am-0102_MG
#   SRA: SRS4899794
#
# Sample Accession: SAMN11950163
#   BioSample: SAMN11950163
#   Sample name: am-0101_MG
#   SRA: SRS4899801
#
# Sample Accession: SAMN11950162
#   BioSample: SAMN11950162
#   Sample name: am-0100_MG
#   SRA: SRS4899802
#
# Sample Accession: SAMN11950161
#   BioSample: SAMN11950161
#   Sample name: am-0099_MG
#   SRA: SRS4899800
#
# Sample Accession: SAMN11950160
#   BioSample: SAMN11950160
#   Sample name: am-0098_MG
#   SRA: SRS4899799
#
# Sample Accession: SAMN11950159
#   BioSample: SAMN11950159
#   Sample name: am-0097_MG
#   SRA: SRS4899649
#
# Sample Accession: SAMN11950158
#   BioSample: SAMN11950158
#   Sample name: am-0096_MG
#   SRA: SRS4899650
#
# Sample Accession: SAMN11950157
#   BioSample: SAMN11950157
#   Sample name: am-0095_MG
#   SRA: SRS4899858
#
# Sample Accession: SAMN11950156
#   BioSample: SAMN11950156
#   Sample name: am-0094_MG
#   SRA: SRS4899861
#
# Sample Accession: SAMN11950155
#   BioSample: SAMN11950155
#   Sample name: am-0093_MG
#   SRA: SRS4899856
#
# Sample Accession: SAMN11950154
#   BioSample: SAMN11950154
#   Sample name: am-0092_MG
#   SRA: SRS4899857
#
# Sample Accession: SAMN11950153
#   BioSample: SAMN11950153
#   Sample name: am-0091_MG
#   SRA: SRS4899732
#
# Sample Accession: SAMN11950152
#   BioSample: SAMN11950152
#   Sample name: am-0090_MG
#   SRA: SRS4899855
#
# Sample Accession: SAMN11950151
#   BioSample: SAMN11950151
#   Sample name: am-0089_MG
#   SRA: SRS4899843
#
# Sample Accession: SAMN11950150
#   BioSample: SAMN11950150
#   Sample name: am-0088_MG
#   SRA: SRS4899655
#
# Sample Accession: SAMN11950149
#   BioSample: SAMN11950149
#   Sample name: am-0087_MG
#   SRA: SRS4899511
#
# Sample Accession: SAMN11950148
#   BioSample: SAMN11950148
#   Sample name: am-0086_MG
#   SRA: SRS4899510
#
# Sample Accession: SAMN11950147
#   BioSample: SAMN11950147
#   Sample name: am-0085_MG
#   SRA: SRS4899486
#
# Sample Accession: SAMN11950146
#   BioSample: SAMN11950146
#   Sample name: am-0084_MG
#   SRA: SRS4899485
#
# Sample Accession: SAMN11950145
#   BioSample: SAMN11950145
#   Sample name: am-0083_MG
#   SRA: SRS4899913
#
# Sample Accession: SAMN11950144
#   BioSample: SAMN11950144
#   Sample name: am-0082_MG
#   SRA: SRS4899489
#
# Sample Accession: SAMN11950143
#   BioSample: SAMN11950143
#   Sample name: am-0081_MG
#   SRA: SRS4899480
#
# Sample Accession: SAMN11950142
#   BioSample: SAMN11950142
#   Sample name: am-0080_MG
#   SRA: SRS4899481
#
# Sample Accession: SAMN11950141
#   BioSample: SAMN11950141
#   Sample name: am-0079_MG
#   SRA: SRS4899484
#
# Sample Accession: SAMN11950140
#   BioSample: SAMN11950140
#   Sample name: am-0078_MG
#   SRA: SRS4899515
#
# Sample Accession: SAMN11950139
#   BioSample: SAMN11950139
#   Sample name: am-0077_MG
#   SRA: SRS4899902
#
# Sample Accession: SAMN11950138
#   BioSample: SAMN11950138
#   Sample name: am-0076_MG
#   SRA: SRS4899903
#
# Sample Accession: SAMN11950137
#   BioSample: SAMN11950137
#   Sample name: am-0075_MG
#   SRA: SRS4899904
#
# Sample Accession: SAMN11950136
#   BioSample: SAMN11950136
#   Sample name: am-0074_MG
#   SRA: SRS4899905
#
# Sample Accession: SAMN11950135
#   BioSample: SAMN11950135
#   Sample name: am-0073_MG
#   SRA: SRS4899906
#
# Sample Accession: SAMN11950134
#   BioSample: SAMN11950134
#   Sample name: am-0072_MG
#   SRA: SRS4899907
#
# Sample Accession: SAMN11950133
#   BioSample: SAMN11950133
#   Sample name: am-0071_MG
#   SRA: SRS4899909
#
# Sample Accession: SAMN11950132
#   BioSample: SAMN11950132
#   Sample name: am-0070_MG
#   SRA: SRS4899910
#
# Sample Accession: SAMN11950131
#   BioSample: SAMN11950131
#   Sample name: am-0069_MG
#   SRA: SRS4899908
#
# Sample Accession: SAMN11950130
#   BioSample: SAMN11950130
#   Sample name: am-0068_MG
#   SRA: SRS4899911
#
# Sample Accession: SAMN11950129
#   BioSample: SAMN11950129
#   Sample name: am-0067_MG
#   SRA: SRS4899693
#
# Sample Accession: SAMN11950128
#   BioSample: SAMN11950128
#   Sample name: am-0066_MG
#   SRA: SRS4899692
#
# Sample Accession: SAMN11950127
#   BioSample: SAMN11950127
#   Sample name: am-0065_MG
#   SRA: SRS4899624
#
# Sample Accession: SAMN11950126
#   BioSample: SAMN11950126
#   Sample name: am-0064_MG
#   SRA: SRS4899483
#
# Sample Accession: SAMN11950125
#   BioSample: SAMN11950125
#   Sample name: am-0063_MG
#   SRA: SRS4899689
#
# Sample Accession: SAMN11950124
#   BioSample: SAMN11950124
#   Sample name: am-0062_MG
#   SRA: SRS4899688
#
# Sample Accession: SAMN11950123
#   BioSample: SAMN11950123
#   Sample name: am-0061_MG
#   SRA: SRS4899687
#
# Sample Accession: SAMN11950122
#   BioSample: SAMN11950122
#   Sample name: am-0060_MG
#   SRA: SRS4899686
#
# Sample Accession: SAMN11950121
#   BioSample: SAMN11950121
#   Sample name: am-0059_MG
#   SRA: SRS4899684
#
# Sample Accession: SAMN11950120
#   BioSample: SAMN11950120
#   Sample name: am-0058_MG
#   SRA: SRS4899685
#
# Sample Accession: SAMN11950119
#   BioSample: SAMN11950119
#   Sample name: am-0057_MG
#   SRA: SRS4899546
#
# Sample Accession: SAMN11950118
#   BioSample: SAMN11950118
#   Sample name: am-0056_MG
#   SRA: SRS4899547
#
# Sample Accession: SAMN11950117
#   BioSample: SAMN11950117
#   Sample name: am-0055_MG
#   SRA: SRS4899539
#
# Sample Accession: SAMN11950116
#   BioSample: SAMN11950116
#   Sample name: am-0054_MG
#   SRA: SRS4899541
#
# Sample Accession: SAMN11950115
#   BioSample: SAMN11950115
#   Sample name: am-0053_MG
#   SRA: SRS4899460
#
# Sample Accession: SAMN11950114
#   BioSample: SAMN11950114
#   Sample name: am-0052_MG
#   SRA: SRS4899841
#
# Sample Accession: SAMN11950113
#   BioSample: SAMN11950113
#   Sample name: am-0051_MG
#   SRA: SRS4899792
#
# Sample Accession: SAMN11950112
#   BioSample: SAMN11950112
#   Sample name: am-0039_MG
#   SRA: SRS4899793
#
# Sample Accession: SAMN11950111
#   BioSample: SAMN11950111
#   Sample name: am-0031_MG
#   SRA: SRS4899791
#
# Sample Accession: SAMN11950110
#   BioSample: SAMN11950110
#   Sample name: am-0030_MG
#   SRA: SRS4899795
#
# Sample Accession: SAMN11950109
#   BioSample: SAMN11950109
#   Sample name: am-0029_MG
#   SRA: SRS4899455
#
# Sample Accession: SAMN11950108
#   BioSample: SAMN11950108
#   Sample name: am-0028_MG
#   SRA: SRS4899453
#
# Sample Accession: SAMN11950107
#   BioSample: SAMN11950107
#   Sample name: am-0027_MG
#   SRA: SRS4899599
#
# Sample Accession: SAMN11950106
#   BioSample: SAMN11950106
#   Sample name: am-0026_MG
#   SRA: SRS4899597
#
# Sample Accession: SAMN11950105
#   BioSample: SAMN11950105
#   Sample name: am-0025_MG
#   SRA: SRS4899988
#
# Sample Accession: SAMN11950104
#   BioSample: SAMN11950104
#   Sample name: am-0024_MG
#   SRA: SRS4899614
#
# Sample Accession: SAMN11950103
#   BioSample: SAMN11950103
#   Sample name: am-0023_MG
#   SRA: SRS4899653
#
# Sample Accession: SAMN11950102
#   BioSample: SAMN11950102
#   Sample name: am-0022_MG
#   SRA: SRS4899648
#
# Sample Accession: SAMN11950101
#   BioSample: SAMN11950101
#   Sample name: am-0021_MG
#   SRA: SRS4899441
#
# Sample Accession: SAMN11950100
#   BioSample: SAMN11950100
#   Sample name: am-0020_MG
#   SRA: SRS4899442
#
# Sample Accession: SAMN11950099
#   BioSample: SAMN11950099
#   Sample name: am-0019_MG
#   SRA: SRS4899527
#
# Sample Accession: SAMN11950098
#   BioSample: SAMN11950098
#   Sample name: am-0018_MG
#   SRA: SRS4899526
#
# Sample Accession: SAMN11950097
#   BioSample: SAMN11950097
#   Sample name: am-0017_MG
#   SRA: SRS4899803
#
# Sample Accession: SAMN11950096
#   BioSample: SAMN11950096
#   Sample name: am-0016_MG
#   SRA: SRS4899806
#
# Sample Accession: SAMN11950095
#   BioSample: SAMN11950095
#   Sample name: am-0015_MG
#   SRA: SRS4899804
#
# Sample Accession: SAMN11950094
#   BioSample: SAMN11950094
#   Sample name: am-0014_MG
#   SRA: SRS4899805
#
# Sample Accession: SAMN11950093
#   BioSample: SAMN11950093
#   Sample name: am-0013_MG
#   SRA: SRS4899809
#
# Sample Accession: SAMN11950092
#   BioSample: SAMN11950092
# ...
#   SRA: SRS4883382
#
# Sample Accession: SAMN11846177
#   BioSample: SAMN11846177
#   Sample name: am_0001_0092_e12
#   SRA: SRS4883377
#
# Sample Accession: SAMN11846176
#   BioSample: SAMN11846176
#   Sample name: am_0001_0092_d8
#   SRA: SRS4883375
#
# Sample Accession: SAMN11846175
#   BioSample: SAMN11846175
#   Sample name: am_0001_0092_d7
#   SRA: SRS4883376
#
# Sample Accession: SAMN11846174
#   BioSample: SAMN11846174
#   Sample name: am_0001_0092_d3
#   SRA: SRS4883374
#
# Sample Accession: SAMN11846173
#   BioSample: SAMN11846173
#   Sample name: am_0001_0092_d2
#   SRA: SRS4883381
#
# Sample Accession: SAMN11846172
#   BioSample: SAMN11846172
#   Sample name: am_0001_0092_d1
#   SRA: SRS4883379
#
# Sample Accession: SAMN11846171
#   BioSample: SAMN11846171
#   Sample name: am_0001_0092_d12
#   SRA: SRS4883380
#
# Sample Accession: SAMN11846170
#   BioSample: SAMN11846170
#   Sample name: am_0001_0092_d10
#   SRA: SRS4883378
#
# Sample Accession: SAMN11846169
#   BioSample: SAMN11846169
#   Sample name: am_0001_0092_c9
#   SRA: SRS4883970
#
# Sample Accession: SAMN11846168
#   BioSample: SAMN11846168
#   Sample name: am_0001_0092_c5
#   SRA: SRS4883971
#
# Sample Accession: SAMN11846167
#   BioSample: SAMN11846167
#   Sample name: am_0001_0092_c3
#   SRA: SRS4883964
#
# Sample Accession: SAMN11846166
#   BioSample: SAMN11846166
#   Sample name: am_0001_0092_c2
#   SRA: SRS4883965
#
# Sample Accession: SAMN11846165
#   BioSample: SAMN11846165
#   Sample name: am_0001_0092_c1
#   SRA: SRS4883962
#
# Sample Accession: SAMN11846164
#   BioSample: SAMN11846164
#   Sample name: am_0001_0092_c12
#   SRA: SRS4883963
#
# Sample Accession: SAMN11846163
#   BioSample: SAMN11846163
#   Sample name: am_0001_0092_c11
#   SRA: SRS4883966
#
# Sample Accession: SAMN11846162
#   BioSample: SAMN11846162
#   Sample name: am_0001_0092_b9
#   SRA: SRS4883969
#
# Sample Accession: SAMN11846161
#   BioSample: SAMN11846161
#   Sample name: am_0001_0092_b8
#   SRA: SRS4883967
#
# Sample Accession: SAMN11846160
#   BioSample: SAMN11846160
#   Sample name: am_0001_0092_b6
#   SRA: SRS4883968
#
# Sample Accession: SAMN11846159
#   BioSample: SAMN11846159
#   Sample name: am_0001_0092_b5
#   SRA: SRS4883692
#
# Sample Accession: SAMN11846158
#   BioSample: SAMN11846158
#   Sample name: am_0001_0092_b2
#   SRA: SRS4883690
#
# Sample Accession: SAMN11846157
#   BioSample: SAMN11846157
#   Sample name: am_0001_0092_b1
#   SRA: SRS4883681
#
# Sample Accession: SAMN11846156
#   BioSample: SAMN11846156
#   Sample name: am_0001_0092_b12
#   SRA: SRS4883680
#
# Sample Accession: SAMN11846155
#   BioSample: SAMN11846155
#   Sample name: am_0001_0092_b11
#   SRA: SRS4883683
#
# Sample Accession: SAMN11846154
#   BioSample: SAMN11846154
#   Sample name: am_0001_0092_b10
#   SRA: SRS4883682
#
# Sample Accession: SAMN11846153
#   BioSample: SAMN11846153
#   Sample name: am_0001_0092_a9
#   SRA: SRS4883685
#
# Sample Accession: SAMN11846152
#   BioSample: SAMN11846152
#   Sample name: am_0001_0092_a8
#   SRA: SRS4883684
#
# Sample Accession: SAMN11846151
#   BioSample: SAMN11846151
#   Sample name: am_0001_0092_a7
#   SRA: SRS4883686
#
# Sample Accession: SAMN11846150
#   BioSample: SAMN11846150
#   Sample name: am_0001_0092_a6
#   SRA: SRS4883687
#
# Sample Accession: SAMN11846149
#   BioSample: SAMN11846149
#   Sample name: am_0001_0092_a5
#   SRA: SRS4883505
#
# Sample Accession: SAMN11846148
#   BioSample: SAMN11846148
#   Sample name: am_0001_0092_a3
#   SRA: SRS4883507
#
# Sample Accession: SAMN11846147
#   BioSample: SAMN11846147
#   Sample name: am_0001_0092_a2
#   SRA: SRS4883506
#
# Sample Accession: SAMN11846146
#   BioSample: SAMN11846146
#   Sample name: am_0001_0092_a12
#   SRA: SRS4883508
#
# Sample Accession: SAMN11846145
#   BioSample: SAMN11846145
#   Sample name: am_0001_0092_a10
#   SRA: SRS4883510
#
# Sample Accession: SAMN11846144
#   BioSample: SAMN11846144
#   Sample name: am_0171_0078_e3
#   SRA: SRS4883509
#
# Sample Accession: SAMN11846143
#   BioSample: SAMN11846143
#   Sample name: af_0058_0066_a5
#   SRA: SRS4883511
#
# Sample Accession: SAMN11846142
#   BioSample: SAMN11846142
#   Sample name: aa_0143_0061_h2-BIS
#   SRA: SRS4883513
#
# Sample Accession: SAMN11846141
#   BioSample: SAMN11846141
#   Sample name: aa_0143_0065_g9
#   SRA: SRS4883512
#
# Sample Accession: SAMN11846140
#   BioSample: SAMN11846140
#   Sample name: aa_0143_0065_g8
#   SRA: SRS4883514
#
# Sample Accession: SAMN11846139
#   BioSample: SAMN11846139
#   Sample name: aa_0143_0065_g7
#   SRA: SRS4883273
#
# Sample Accession: SAMN11846138
#   BioSample: SAMN11846138
#   Sample name: aa_0143_0065_f5
#   SRA: SRS4883272
#
# Sample Accession: SAMN11846137
#   BioSample: SAMN11846137
#   Sample name: aa_0143_0065_e9
#   SRA: SRS4883271
#
# Sample Accession: SAMN11846136
#   BioSample: SAMN11846136
#   Sample name: aa_0143_0065_e5
#   SRA: SRS4883270
#
# Sample Accession: SAMN11846135
#   BioSample: SAMN11846135
#   Sample name: aa_0143_0065_d7
#   SRA: SRS4883269
#
# Sample Accession: SAMN11846134
#   BioSample: SAMN11846134
#   Sample name: aa_0143_0065_d5
#   SRA: SRS4883268
#
# Sample Accession: SAMN11846133
#   BioSample: SAMN11846133
#   Sample name: aa_0143_0065_c6
#   SRA: SRS4883267
#
# Sample Accession: SAMN11846132
#   BioSample: SAMN11846132
#   Sample name: aa_0143_0065_b9
#   SRA: SRS4883266
#
# Sample Accession: SAMN11846131
#   BioSample: SAMN11846131
#   Sample name: aa_0143_0065_b6
#   SRA: SRS4883265
#
# Sample Accession: SAMN11846130
#   BioSample: SAMN11846130
#   Sample name: aa_0143_0065_b5
#   SRA: SRS4883264
#
# Sample Accession: SAMN11846129
#   BioSample: SAMN11846129
#   Sample name: aa_0143_0065_a7
#   SRA: SRS4883448
#
# Sample Accession: SAMN11846128
#   BioSample: SAMN11846128
#   Sample name: aa_0143_0065_a5
#   SRA: SRS4883444
#
# Sample Accession: SAMN11846127
#   BioSample: SAMN11846127
#   Sample name: aa_0143_0061_h3
#   SRA: SRS4883633
#
# Sample Accession: SAMN11846126
#   BioSample: SAMN11846126
#   Sample name: aa_0143_0061_h3-BIS
#   SRA: SRS4883632
#
# Sample Accession: SAMN11846125
#   BioSample: SAMN11846125
#   Sample name: aa_0143_0061_h1-BIS
#   SRA: SRS4883143
#
# Sample Accession: SAMN11846124
#   BioSample: SAMN11846124
#   Sample name: aa_0143_0061_g4
#   SRA: SRS4883596
#
# Sample Accession: SAMN11846123
#   BioSample: SAMN11846123
#   Sample name: aa_0143_0061_g4-BIS
#   SRA: SRS4883636
#
# Sample Accession: SAMN11846122
#   BioSample: SAMN11846122
#   Sample name: aa_0143_0061_g3
#   SRA: SRS4883637
#
# Sample Accession: SAMN11846121
#   BioSample: SAMN11846121
#   Sample name: aa_0143_0061_g3-BIS
#   SRA: SRS4883638
#
# Sample Accession: SAMN11846120
#   BioSample: SAMN11846120
#   Sample name: aa_0143_0061_g1
#   SRA: SRS4883639
#
# Sample Accession: SAMN11846119
#   BioSample: SAMN11846119
#   Sample name: aa_0143_0061_g1-BIS
#   SRA: SRS4883914
#
# Sample Accession: SAMN11846118
#   BioSample: SAMN11846118
#   Sample name: aa_0143_0061_f4
#   SRA: SRS4883913
#
# Sample Accession: SAMN11846117
#   BioSample: SAMN11846117
#   Sample name: aa_0143_0061_f4-BIS
#   SRA: SRS4883922
#
# Sample Accession: SAMN11846116
#   BioSample: SAMN11846116
#   Sample name: aa_0143_0061_f3
#   SRA: SRS4883921
#
# Sample Accession: SAMN11846115
#   BioSample: SAMN11846115
#   Sample name: aa_0143_0061_f3-BIS
#   SRA: SRS4883920
#
# Sample Accession: SAMN11846114
#   BioSample: SAMN11846114
#   Sample name: aa_0143_0061_f2
#   SRA: SRS4883919
#
# Sample Accession: SAMN11846113
#   BioSample: SAMN11846113
#   Sample name: aa_0143_0061_f1
#   SRA: SRS4883918
#
# Sample Accession: SAMN11846112
#   BioSample: SAMN11846112
#   Sample name: aa_0143_0061_f1-BIS
#   SRA: SRS4883917
#
# Sample Accession: SAMN11846111
#   BioSample: SAMN11846111
#   Sample name: aa_0143_0061_e4
#   SRA: SRS4883916
#
# Sample Accession: SAMN11846110
#   BioSample: SAMN11846110
#   Sample name: aa_0143_0061_e4-BIS
#   SRA: SRS4883915
#
# Sample Accession: SAMN11846109
#   BioSample: SAMN11846109
#   Sample name: aa_0143_0061_e3
#   SRA: SRS4883240
#
# Sample Accession: SAMN11846108
#   BioSample: SAMN11846108
#   Sample name: aa_0143_0061_e3-BIS
#   SRA: SRS4883241
#
# Sample Accession: SAMN11846107
#   BioSample: SAMN11846107
#   Sample name: aa_0143_0061_e2-BIS
#   SRA: SRS4883234
#
# Sample Accession: SAMN11846106
#   BioSample: SAMN11846106
#   Sample name: aa_0143_0061_e1
#   SRA: SRS4883235
#
# Sample Accession: SAMN11846105
#   BioSample: SAMN11846105
#   Sample name: aa_0143_0061_e1-BIS
#   SRA: SRS4883232
#
# Sample Accession: SAMN11846104
#   BioSample: SAMN11846104
#   Sample name: aa_0143_0061_d3
#   SRA: SRS4883233
#
# Sample Accession: SAMN11846103
#   BioSample: SAMN11846103
#   Sample name: aa_0143_0061_d3-BIS
#   SRA: SRS4883238
#
# Sample Accession: SAMN11846102
#   BioSample: SAMN11846102
#   Sample name: aa_0143_0061_d2
#   SRA: SRS4883239
#
# Sample Accession: SAMN11846101
#   BioSample: SAMN11846101
#   Sample name: aa_0143_0061_d2-BIS
#   SRA: SRS4883236
#
# Sample Accession: SAMN11846100
#   BioSample: SAMN11846100
#   Sample name: aa_0143_0061_d1
#   SRA: SRS4883237
#
# Sample Accession: SAMN11846099
#   BioSample: SAMN11846099
#   Sample name: aa_0143_0061_d1-BIS
#   SRA: SRS4883154
#
# Sample Accession: SAMN11846098
#   BioSample: SAMN11846098
#   Sample name: aa_0143_0061_c4
#   SRA: SRS4883152
#
# Sample Accession: SAMN11846097
#   BioSample: SAMN11846097
#   Sample name: aa_0143_0061_c4-BIS
#   SRA: SRS4883145
#
# Sample Accession: SAMN11846096
#   BioSample: SAMN11846096
#   Sample name: aa_0143_0061_c3
#   SRA: SRS4883144
#
# Sample Accession: SAMN11846095
#   BioSample: SAMN11846095
#   Sample name: aa_0143_0061_c3-BIS
#   SRA: SRS4883147
#
# Sample Accession: SAMN11846094
#   BioSample: SAMN11846094
#   Sample name: aa_0143_0061_c3-BISb
#   SRA: SRS4883146
#
# Sample Accession: SAMN11846093
#   BioSample: SAMN11846093
#   Sample name: aa_0143_0061_c2
#   SRA: SRS4883149
#
# Sample Accession: SAMN11846092
#   BioSample: SAMN11846092
#   Sample name: aa_0143_0061_c2-BIS
#   SRA: SRS4883148
#
# Sample Accession: SAMN11846091
#   BioSample: SAMN11846091
#   Sample name: aa_0143_0061_c1
#   SRA: SRS4883151
#
# Sample Accession: SAMN11846090
#   BioSample: SAMN11846090
#   Sample name: aa_0143_0061_c1-BIS
#   SRA: SRS4883150
#
# Sample Accession: SAMN11846089
#   BioSample: SAMN11846089
#   Sample name: aa_0143_0061_b4-BIS
#   SRA: SRS4883774
#
# Sample Accession: SAMN11846088
#   BioSample: SAMN11846088
#   Sample name: aa_0143_0061_b3
#   SRA: SRS4883776
#
# Sample Accession: SAMN11846087
#   BioSample: SAMN11846087
#   Sample name: aa_0143_0061_b3-BIS
#   SRA: SRS4883768
#
# Sample Accession: SAMN11846086
#   BioSample: SAMN11846086
#   Sample name: aa_0143_0061_b2
#   SRA: SRS4883771
#
# Sample Accession: SAMN11846085
#   BioSample: SAMN11846085
#   Sample name: aa_0143_0061_b1
#   SRA: SRS4883772
#
# Sample Accession: SAMN11846084
#   BioSample: SAMN11846084
#   Sample name: aa_0143_0061_b1-BIS
#   SRA: SRS4883773
#
# Sample Accession: SAMN11846083
#   BioSample: SAMN11846083
#   Sample name: aa_0143_0061_a4
#   SRA: SRS4883766
#
# Sample Accession: SAMN11846082
#   BioSample: SAMN11846082
#   Sample name: aa_0143_0061_a4-BIS
#   SRA: SRS4883767
#
# Sample Accession: SAMN11846081
#   BioSample: SAMN11846081
#   Sample name: aa_0143_0061_a3
#   SRA: SRS4883769
#
# Sample Accession: SAMN11846080
#   BioSample: SAMN11846080
#   Sample name: aa_0143_0061_a3-BIS
#   SRA: SRS4883770
#
# Sample Accession: SAMN11846079
#   BioSample: SAMN11846079
#   Sample name: aa_0143_0061_a2-BIS
#   SRA: SRS4884104
#
# Sample Accession: SAMN11846078
#   BioSample: SAMN11846078
#   Sample name: aa_0143_0061_a1
#   SRA: SRS4884103
#
# Sample Accession: SAMN11846077
#   BioSample: SAMN11846077
#   Sample name: aa_0143_0061_a1-BIS
#   SRA: SRS4884108
#
# Sample Accession: SAMN11846076
#   BioSample: SAMN11846076
#   Sample name: aa_0143_0055_h3
#   SRA: SRS4884107
#
# Sample Accession: SAMN11846075
#   BioSample: SAMN11846075
#   Sample name: aa_0143_0055_b3
#   SRA: SRS4884106
#
# Sample Accession: SAMN11846074
#   BioSample: SAMN11846074
#   Sample name: am_0224_0086_h5
#   SRA: SRS4884105
#
# Sample Accession: SAMN11846073
#   BioSample: SAMN11846073
#   Sample name: am_0224_0086_h4
#   SRA: SRS4884112
#
# Sample Accession: SAMN11846072
#   BioSample: SAMN11846072
#   Sample name: am_0224_0086_h3
#   SRA: SRS4884111
#
# Sample Accession: SAMN11846071
#   BioSample: SAMN11846071
#   Sample name: am_0224_0086_h2
#   SRA: SRS4884109
#
# Sample Accession: SAMN11846070
#   BioSample: SAMN11846070
#   Sample name: am_0224_0086_g4
#   SRA: SRS4884110
#
# Sample Accession: SAMN11846069
#   BioSample: SAMN11846069
#   Sample name: am_0224_0086_g1
#   SRA: SRS4883411
#
# Sample Accession: SAMN11846068
#   BioSample: SAMN11846068
#   Sample name: am_0224_0086_f6
#   SRA: SRS4883412
#
# Sample Accession: SAMN11846067
#   BioSample: SAMN11846067
#   Sample name: am_0224_0086_f5
#   SRA: SRS4883420
#
# Sample Accession: SAMN11846066
#   BioSample: SAMN11846066
#   Sample name: am_0224_0086_f3
#   SRA: SRS4883421
#
# Sample Accession: SAMN11846065
#   BioSample: SAMN11846065
#   Sample name: am_0224_0086_e6
#   SRA: SRS4883418
#
# Sample Accession: SAMN11846064
#   BioSample: SAMN11846064
#   Sample name: am_0224_0086_e5
#   SRA: SRS4883419
#
# Sample Accession: SAMN11846063
#   BioSample: SAMN11846063
#   Sample name: am_0224_0086_e3
#   SRA: SRS4883416
#
# Sample Accession: SAMN11846062
#   BioSample: SAMN11846062
#   Sample name: am_0224_0086_e2
#   SRA: SRS4883417
#
# Sample Accession: SAMN11846061
#   BioSample: SAMN11846061
#   Sample name: am_0224_0086_d6
#   SRA: SRS4883414
#
# Sample Accession: SAMN11846060
#   BioSample: SAMN11846060
#   Sample name: am_0224_0086_d5
#   SRA: SRS4883415
#
# Sample Accession: SAMN11846059
#   BioSample: SAMN11846059
#   Sample name: am_0224_0086_d3
#   SRA: SRS4883669
#
# Sample Accession: SAMN11846058
#   BioSample: SAMN11846058
#   Sample name: am_0224_0086_d2
#   SRA: SRS4883668
#
# Sample Accession: SAMN11846057
#   BioSample: SAMN11846057
#   Sample name: am_0224_0086_d1
#   SRA: SRS4883675
#
# Sample Accession: SAMN11846056
#   BioSample: SAMN11846056
#   Sample name: am_0224_0086_c6
#   SRA: SRS4883674
#
# Sample Accession: SAMN11846055
#   BioSample: SAMN11846055
#   Sample name: am_0224_0086_c5
#   SRA: SRS4883678
#
# Sample Accession: SAMN11846054
#   BioSample: SAMN11846054
#   Sample name: am_0224_0086_b6
#   SRA: SRS4883677
#
# Sample Accession: SAMN11846053
#   BioSample: SAMN11846053
#   Sample name: am_0224_0086_b5
#   SRA: SRS4883672
#
# Sample Accession: SAMN11846052
#   BioSample: SAMN11846052
#   Sample name: am_0224_0086_a5
#   SRA: SRS4883670
#
# Sample Accession: SAMN11846051
#   BioSample: SAMN11846051
#   Sample name: am_0224_0086_a4
#   SRA: SRS4883673
#
# Sample Accession: SAMN11846050
#   BioSample: SAMN11846050
#   Sample name: am_0224_0080_d9
#   SRA: SRS4883671
#
# Sample Accession: SAMN11846049
#   BioSample: SAMN11846049
#   Sample name: am_0171_0071_h7
#   SRA: SRS4883958
#
# Sample Accession: SAMN11846048
#   BioSample: SAMN11846048
#   Sample name: am_0171_0071_g9
#   SRA: SRS4883960
#
# Sample Accession: SAMN11846047
#   BioSample: SAMN11846047
#   Sample name: am_0171_0071_g7
#   SRA: SRS4883949
#
# Sample Accession: SAMN11846046
#   BioSample: SAMN11846046
#   Sample name: am_0171_0071_g12
#   SRA: SRS4883950
#
# Sample Accession: SAMN11846045
#   BioSample: SAMN11846045
#   Sample name: am_0171_0071_f9
#   SRA: SRS4883952
#
# Sample Accession: SAMN11846044
#   BioSample: SAMN11846044
#   Sample name: am_0171_0071_f10
#   SRA: SRS4883951
#
# Sample Accession: SAMN11846043
#   BioSample: SAMN11846043
#   Sample name: am_0171_0071_e8
#   SRA: SRS4883953
#
# Sample Accession: SAMN11846042
#   BioSample: SAMN11846042
#   Sample name: am_0171_0071_e11
#   SRA: SRS4883954
#
# Sample Accession: SAMN11846041
#   BioSample: SAMN11846041
#   Sample name: am_0171_0071_e10
#   SRA: SRS4883955
#
# Sample Accession: SAMN11846040
#   BioSample: SAMN11846040
#   Sample name: am_0171_0071_c9
#   SRA: SRS4883956
#
# Sample Accession: SAMN11846039
#   BioSample: SAMN11846039
#   Sample name: am_0171_0071_c12
#   SRA: SRS4883617
#
# Sample Accession: SAMN11846038
#   BioSample: SAMN11846038
#   Sample name: am_0171_0071_b10
#   SRA: SRS4883618
#
# Sample Accession: SAMN11846037
#   BioSample: SAMN11846037
#   Sample name: am_0171_0066_e8
#   SRA: SRS4883613
#
# Sample Accession: SAMN11846036
#   BioSample: SAMN11846036
#   Sample name: am_0171_0066_c8
#   SRA: SRS4883614
#
# Sample Accession: SAMN11846035
#   BioSample: SAMN11846035
#   Sample name: am_0014_0091_e9
#   SRA: SRS4883615
#
# Sample Accession: SAMN11846034
#   BioSample: SAMN11846034
#   Sample name: am_0014_0091_c7
#   SRA: SRS4883616
#
# Sample Accession: SAMN11846033
#   BioSample: SAMN11846033
#   Sample name: am_0014_0091_b8
#   SRA: SRS4883609
#
# Sample Accession: SAMN11846032
#   BioSample: SAMN11846032
#   Sample name: am_0014_0091_b12
#   SRA: SRS4883610
#
# Sample Accession: SAMN11846031
#   BioSample: SAMN11846031
#   Sample name: am_0014_0091_a12
#   SRA: SRS4883611
#
# Sample Accession: SAMN11846030
#   BioSample: SAMN11846030
#   Sample name: am_0014_0091_a10
#   SRA: SRS4883612

# %%
# Convert to dataframe
df = pd.DataFrame(sample_ids).T
df
# Out:
#                  BioSample       Sample name         SRA
# SAMN11950562  SAMN11950562        dl-0006_MG  SRS4899508
# SAMN11950561  SAMN11950561        dl-0001_MG  SRS4899507
# SAMN11950560  SAMN11950560        dk-0003_MG  SRS4899944
# SAMN11950559  SAMN11950559        dk-0001_MG  SRS4899890
# SAMN11950558  SAMN11950558        dj-0016_MG  SRS4899891
# ...                    ...               ...         ...
# SAMN11846034  SAMN11846034   am_0014_0091_c7  SRS4883616
# SAMN11846033  SAMN11846033   am_0014_0091_b8  SRS4883609
# SAMN11846032  SAMN11846032  am_0014_0091_b12  SRS4883610
# SAMN11846031  SAMN11846031  am_0014_0091_a12  SRS4883611
# SAMN11846030  SAMN11846030  am_0014_0091_a10  SRS4883612
#
# [8995 rows x 3 columns]

# %%
from collections import Counter

all_suffixes = Counter([str(x).split(" ")[-1].split("_")[-1].split("-")[-1] for x in df["Sample name"]])
all_suffixes.most_common(10)
# Out:
# [('WGS', 3632),
#  ('16S', 1168),
#  ('MG', 563),
#  ('BIS', 103),
#  ('e2', 49),
#  ('g5', 48),
#  ('e3', 48),
#  ('d2', 48),
#  ('c2', 47),
#  ('b3', 47)]

# %%
mapping = {}
for i, row in df.iterrows():
    if row["Sample name"].endswith("16S"):
        name = str(row["Sample name"])[:-4]
        info = {"16S SRA": row["SRA"], "16S Biosample": row["BioSample"]}
    elif row["Sample name"].endswith("WGS"):
        name = str(row["Sample name"])[:-4]
        info = {"WGS SRA": row["SRA"], "WGS Biosample": row["BioSample"]}
    else:
        continue  # Skip samples that don't have either

    if name not in mapping:
        mapping[name] = {}
    # mapping[name].update(info)
    for k, v in info.items():
        mapping[name][k] = v

# Convert to dataframe
df_mapping = pd.DataFrame(mapping).T
# df_mapping = df_mapping[df_mapping["16S SRA"].notnull() | df_mapping["WGS SRA"].notnull()]
df_mapping
# Out:
#                 WGS SRA WGS Biosample     16S SRA 16S Biosample
# bj_0095_0068_d7     NaN  SAMN11946669         NaN           NaN
# bj_0095_0068_c6     NaN  SAMN11946668         NaN           NaN
# bj_0095_0068_g5     NaN  SAMN11946667         NaN           NaN
# bj_0095_0068_b6     NaN  SAMN11946666         NaN           NaN
# bj_0095_0068_a7     NaN  SAMN11946665         NaN           NaN
# ...                 ...           ...         ...           ...
# ac-0038             NaN           NaN  SRS4894852  SAMN11941247
# ac-0002             NaN           NaN  SRS4894860  SAMN11941246
# ab-0140             NaN           NaN  SRS4894858  SAMN11941245
# aa-0163             NaN           NaN  SRS4894859  SAMN11941244
# aa-0154             NaN           NaN  SRS4894856  SAMN11941243
#
# [4800 rows x 4 columns]

# %%
# Ok, we should take another approach. Here's the metadata from the paper
# !pip install openpyxl
import pandas as pd

metadata = pd.read_excel("../../data/bioml/41591_2019_559_MOESM3_ESM.xlsx", sheet_name="SupTable3", header=1)
ids = metadata[(metadata[["16S", "metagenomes"]] == "YES").all(axis=1)]["sample-id"]
# Out:
# /home/phil/mambaforge/envs/aptr/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Check how many of the IDs match via the mapping:
# name_MG --> WGS
# name_16S --> 16S

matching = 0
mg = 0
s16 = 0
total = 0
for id in ids:
    total += 1
    if df["Sample name"].str.startswith(id).any():
        matching += 1
        if (df["Sample name"] == id + "_MG").any():
            mg += 1
        if (df["Sample name"] == id + "_16S").any():
            s16 += 1

matching, total, mg, s16

# Ok great, it's a perfect match.
# Out:
# (541, 541, 541, 541)

# %%
# Well, let's build our dataframe

df_reindexed = df.set_index("Sample name")
sra_df = pd.DataFrame(columns=["WGS SRA", "WGS Biosample", "16S SRA", "16S Biosample"])
for id in ids:
    sra_df.loc[id] = [
        df_reindexed.loc[id + "_MG"]["SRA"],
        df_reindexed.loc[id + "_MG"]["BioSample"],
        df_reindexed.loc[id + "_16S"]["SRA"],
        df_reindexed.loc[id + "_16S"]["BioSample"],
    ]
sra_df
# Out:
#             WGS SRA WGS Biosample     16S SRA 16S Biosample
# aa-0154  SRS4899874  SAMN11950000  SRS4894856  SAMN11941243
# aa-0163  SRS4899871  SAMN11950001  SRS4894859  SAMN11941244
# ab-0140  SRS4899875  SAMN11950002  SRS4894858  SAMN11941245
# ac-0002  SRS4899924  SAMN11950004  SRS4894860  SAMN11941246
# ac-0038  SRS4899923  SAMN11950005  SRS4894852  SAMN11941247
# ...             ...           ...         ...           ...
# dj-0016  SRS4899891  SAMN11950558  SRS4895434  SAMN11942406
# dk-0001  SRS4899890  SAMN11950559  SRS4895431  SAMN11942407
# dk-0003  SRS4899944  SAMN11950560  SRS4895432  SAMN11942408
# dl-0001  SRS4899507  SAMN11950561  SRS4895429  SAMN11942409
# dl-0006  SRS4899508  SAMN11950562  SRS4895430  SAMN11942410
#
# [541 rows x 4 columns]

# %%
# And while we're at it, let's go ahead and dump the 16S and WGS reads!

import os
from tqdm import tqdm

# Verify we have fastq-dump
print(os.system("fastq-dump --version"))

# Start with 16S
# for seqtype in ["16S", "WGS"]:
for seqtype in ["WGS"]:  # Re-run this later
    os.makedirs(f"/home/phil/DATA1/bioml/{seqtype}", exist_ok=True)
    os.makedirs(f"../../data/bioml/reads/{seqtype}", exist_ok=True)
    for id in tqdm(ids):
        # print(f"Dumping {seqtype} reads for {id}")
        sra = sra_df.loc[id][f"{seqtype} Biosample"]
        os.system(f"fastq-dump --split-files {sra} -O ~/DATA1/bioml/{seqtype}/ > /dev/null 2>&1")

        # Add symlinks: Data1/.../SRA <-- reads/.../id
        os.system(
            f"ln -s ~/DATA1/bioml/{seqtype}/{sra}_1.fastq ../../data/bioml/reads/{seqtype}/{id}_1.fastq > /dev/null 2>&1"
        )
        os.system(
            f"ln -s ~/DATA1/bioml/{seqtype}/{sra}_2.fastq ../../data/bioml/reads/{seqtype}/{id}_2.fastq > /dev/null 2>&1"
        )
# Out:
# fastq-dump : 3.1.1
#
# 0
# 100%|██████████| 541/541 [53:51<00:00,  5.97s/it]
#   0%|          | 2/541 [16:24<72:40:33, 485.40s/it]
